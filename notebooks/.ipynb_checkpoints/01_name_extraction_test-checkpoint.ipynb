# %%
from pathlib import Path

# %%
data_path = Path("data/raw/parallel-n")
files = list(data_path.glob("*"))[:5]
files
# Out:
# [PosixPath('data/raw/parallel-n/IITB.en-hi.en'),
#  PosixPath('data/raw/parallel-n/IITB.en-hi.hi')]

# %%
en_file = "data/raw/parallel-n/IITB.en-hi.en"
hi_file = "data/raw/parallel-n/IITB.en-hi.hi"

with open(en_file, encoding = "utf-8") as f_en, open(hi_file, encoding = "utf-8") as f_hi:
    for i in range(10):
        en_line = f_en.readline().strip()
        hi_line = f_hi.readline().strip()
        print(f"{i+1}. EN: {en_line}")
        print(f"   HI: {hi_line}")
        print("-" * 50)
# Out:
# 1. EN: Give your application an accessibility workout
#    HI: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# --------------------------------------------------
# 2. EN: Accerciser Accessibility Explorer
#    HI: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# --------------------------------------------------
# 3. EN: The default plugin layout for the bottom panel
#    HI: निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# --------------------------------------------------
# 4. EN: The default plugin layout for the top panel
#    HI: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# --------------------------------------------------
# 5. EN: A list of plugins that are disabled by default
#    HI: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# --------------------------------------------------
# 6. EN: Highlight duration
#    HI: अवधि को हाइलाइट रकें
# --------------------------------------------------
# 7. EN: The duration of the highlight box when selecting accessible nodes
#    HI: पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# --------------------------------------------------
# 8. EN: Highlight border color
#    HI: सीमांत (बोर्डर) के रंग को हाइलाइट करें
# --------------------------------------------------
# 9. EN: The color and opacity of the highlight border.
#    HI: हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# --------------------------------------------------
# 10. EN: Highlight fill color
#    HI: भराई के रंग को हाइलाइट करें
# --------------------------------------------------

# %%
import spacy

# %%
#NER ALONE DIDN'T WORK

# %%
nlp = spacy.load("en_core_web_sm")
sentence = "Accerciser Accessibility Explorer"
doc = nlp(sentence)
for ent in doc.ents:
    print(ent.text, ent.label_)

# %%
#COMBINING NER AND HEURISTICS (HYBRID)

# %%
# Load English NLP pipeline
nlp = spacy.load("en_core_web_sm", disable = ["parser", "tagger", "lemmatizer"])

en_file = Path("data/raw/parallel-n/IITB.en-hi.en")

extracted_names = set()

MAX_LINES = 10000

with open(en_file, encoding="utf-8") as f:
    lines = []
    for i, line in enumerate(f):
        if i >= MAX_LINES:
            break
        line = line.strip()
        if line:
            lines.append(line)

print(f"Processing {len(lines)} sentences...")

# Process in batches
for doc in nlp.pipe(lines, batch_size = 500):
    # Part 1: NER
    for ent in doc.ents:
        if ent.label_ in {"PERSON", "ORG", "PRODUCT", "GPE"}:
            extracted_names.add(ent.text)

    # Part 2: Heuristics
    for token in doc:
        if(
            token.text[0].isupper() and
            token.is_alpha and
            len(token.text) > 2
        ):
            extracted_names.add(token.text)

print("Done")
print("Total extracted names: ", len(extracted_names))
list(extracted_names)[:20]
# Out:
# Processing 10000 sentences...
# Done
# Total extracted names:  1227
# ['Log',
#  'Move',
#  'Searching',
#  'Children',
#  'King',
#  'Blondes',
#  'Note',
#  'NOTICE',
#  'Execute Program',
#  'Actions',
#  'Change',
#  'Category',
#  'Scratchbox Options',
#  'High',
#  'Medium',
#  'Spider Three Decks',
#  'Glenwood',
#  'Condition',
#  'Next Message',
#  'Thai']

# %%
import json

with open("data/processed/extracted_names_en_10k.json", "w", encoding = "utf-8") as f:
    json.dump(sorted(extracted_names), f, ensure_ascii = False, indent = 2)

# %%
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate
from difflib import SequenceMatcher

# %%
# ==========================================================
# BASELINE ALIGNMENT PIPELINE (DISABLED – NOT USED IN RESULTS)
# ==========================================================
# nlp = spacy.load("en_core_web_sm", disable=["parser", "tagger", "lemmatizer"])
# ...
# json.dump(aligned_pairs, f, ensure_ascii=False, indent=2)

# %%
# nlp = spacy.load("en_core_web_sm", disable=["parser", "tagger", "lemmatizer"])

# def romanize_hi(word):
#     return transliterate(word, sanscript.DEVANAGARI, sanscript.ITRANS)

# def similarity(a,b):
#     return SequenceMatcher(None, a.lower(), b.lower()).ratio()

# en_file = Path("data/raw/parallel-n/IITB.en-hi.en")
# hi_file = Path("data/raw/parallel-n/IITB.en-hi.hi")

# MAX_LINES = 10000

# en_lines, hi_lines = [], []

# with open(en_file, encoding = "utf-8") as f_en , open(hi_file, encoding = "utf-8") as f_hi:
#     for i, (en, hi) in enumerate(zip(f_en, f_hi)):
#         if i >= MAX_LINES:
#             break
#         en_lines.append(en.strip())
#         hi_lines.append(hi.strip())

# aligned_pairs = []

# for en_sent, hi_sent in zip(en_lines, hi_lines):
#     doc = nlp(en_sent)

#     en_names = set()

#     for ent in doc.ents:
#         if ent.label_ in {"PERSON", "ORG", "PRODUCT", "GPE"}:
#             en_names.add(ent.text)

#     for token in doc:
#         if token.text[0].isupper() and token.is_alpha and len(token.text) > 2:
#             en_names.add(token.text)

#     if not en_names:
#         continue

#     hi_tokens = hi_sent.split()

#     for en_name in en_names:
#         best_match = None
#         best_score = 0.0

#         for hi_word in hi_tokens:
#             if len(hi_word) < 2:
#                 continue

#             hi_roman = romanize_hi(hi_word)
#             score = similarity(en_name, hi_roman)

#             if score > best_score:
#                 best_score = score
#                 best_match = hi_word

#         if best_score >= 0.45:
#             aligned_pairs.append((en_name, best_match, best_score))

# for pair in aligned_pairs[:20]:
#     print(pair)
# Out:
# ('Highlight', 'हाइलाइट', 0.5882352941176471)
# ('Highlight', 'हाइलाइट', 0.5882352941176471)
# ('Highlight', 'हाइलाइट', 0.5882352941176471)
# ('API', 'एपीआई', 0.5)
# ('Hide', 'छिपाएं', 0.5454545454545454)
# ('Console', 'कन्सोल', 0.5714285714285714)
# ('IPython', 'आईपाइथन', 0.5882352941176471)
# ('Monitor', 'मानिटर', 0.6666666666666666)
# ('Monitor', 'मानिटर', 0.6666666666666666)
# ('Highlight', 'हाइलाइट', 0.5882352941176471)
# ('WIDGET', 'विडजेट', 0.5714285714285714)
# ('Alpha', 'अल्फा', 1.0)
# ('Des', 'डेस्कटोप', 0.5)
# ('Position', 'स्थिति', 0.5714285714285714)
# ('Offset', 'ओफसेट', 0.5714285714285714)
# ('Name', 'नाम', 0.75)
# ('URI', 'यूआरआई', 0.6)
# ('Plugin', 'प्लग-इन', 0.6666666666666666)
# ('Native', 'वतनी', 0.5)
# ('LDTP', 'एलडीटीपी', 0.6153846153846154)

# %%
# import json

# with open("data/processed/aligned_pairs_10k.json", "w", encoding = "utf-8") as f:
#     json.dump(aligned_pairs, f, ensure_ascii = False, indent = 2)

# %%
import json

with open("data/processed/aligned_pairs_10k.json", encoding = "utf-8") as f:
    aligned_pairs = json.load(f)

# %%
deduped = {}

for en, hi, score in aligned_pairs:
    key = (en.lower(), hi)

    if key not in deduped or score > deduped[key][2]:
        deduped[key] = (en, hi, score)

# %%
deduped_pairs = list(deduped.values())

# %%
COMMON_ENGLISH = {
    "the", "this", "that", "these", "those", 
    "data", "report", "give", "allow", "show", "hide", 
    "name", "position", "default", "settings", "file", 
    "view", "edit", "help", "use", "using", "used", 
    "set", "get", "add", "remove"
}

# %%
COMMON_HINDI = {
    "से", "में", "का", "की", "के", "को", "पर",
    "है", "था", "थी", "थे", "असमर्थ", "संग्रहित",
    "लिए", "द्वारा", "साथ", "बिना"
}

# %%
filtered_pairs = []

for en, hi, score in deduped_pairs:
    if en.lower() in COMMON_ENGLISH:
        continue
    filtered_pairs.append((en, hi, score))

print("Before: ", len(aligned_pairs))
print("After dedup: ", len(deduped_pairs))
print("After filtering: ", len(filtered_pairs))

for pair in filtered_pairs[:20]:
    print(pair)
# Out:
# Before:  3581
# After dedup:  667
# After filtering:  631
# ('Highlight', 'हाइलाइट', 0.5882352941176471)
# ('API', 'एपीआई', 0.5)
# ('Console', 'कन्सोल', 0.5714285714285714)
# ('IPython', 'आईपाइथन', 0.5882352941176471)
# ('Monitor', 'मानिटर', 0.6666666666666666)
# ('WIDGET', 'विडजेट', 0.5714285714285714)
# ('Alpha', 'अल्फा', 1.0)
# ('Des', 'डेस्कटोप', 0.5)
# ('Offset', 'ओफसेट', 0.5714285714285714)
# ('URI', 'यूआरआई', 0.6)
# ('Plugin', 'प्लग-इन', 0.6666666666666666)
# ('Native', 'वतनी', 0.5)
# ('LDTP', 'एलडीटीपी', 0.6153846153846154)
# ('Recorder', 'रेकोर्डर', 0.7058823529411765)
# ('Creates', 'करता', 0.46153846153846156)
# ('num1', '(num1)', 0.8)
# ('Accerciser', 'इसे', 0.46153846153846156)
# ('Changes', 'आएंगे।', 0.46153846153846156)
# ('Node', '(नोड)', 0.6)
# ('Alt', 'आल्ट', 0.8571428571428571)

# %%
with open("data/processed/aligned_pairs_10k_clean.json", "w", encoding = "utf-8") as f:
    json.dump(filtered_pairs, f, ensure_ascii = False, indent = 2)

# %%
#ALIGNMENT

# %%
import re

MAX_LINES = 100000
OUTPUT_TAG = "100k"

SIM_THRESHOLD = 0.5

COMMON_ENGLISH = {
    "the", "this", "that", "these", "those", 
    "data", "report", "give", "allow", "show", "hide", 
    "name", "position", "default", "settings", "file", 
    "view", "edit", "help", "use", "using", "used", 
    "set", "get", "add", "remove"
}

SEMANTIC_IDENTIFIER_WORDS = {
    "name", "display", "value", "default", "file",
    "user", "setting", "config", "option", "property",
    "area", "reset", "mode", "type", "level", "status"
}

COMMON_HINDI = {
    "से", "में", "का", "की", "के", "को", "पर",
    "है", "था", "थी", "थे", "असमर्थ", "संग्रहित",
    "लिए", "द्वारा", "साथ", "बिना"
}

DEMONYM_TRANSLATIONS = {
    "अमेरिकी", "ब्रिटिश", "भारतीय", "चीनी", "जापानी"
}

BAD_ENGLISH = {
    "american", "british", "baltic", "hungarian",
    "european", "african", "asian", "arab"
}

ENGLISH_DEMONYMS = {
    "america", "american", "turkish", "british", "french",
    "german", "italian", "spanish", "chinese", "japanese",
    "indian", "european", "african", "asian"
}

DIRECTIONAL_ADJECTIVES = {
    "western", "eastern", "northern", "southern",
    "central", "global", "local"
}
    
nlp = spacy.load("en_core_web_sm", disable = ["parser", "lemmatizer"])

def is_title_like(doc):
    """
    Heuristic: sentence is title-like if it has no verb
    """
    return not any(token.pos_ == "VERB" for token in doc)

def is_devanagari(word):
    """
    Returns true if all characters in the word are Devanagari
    """
    return all('\u0900' <= ch <= '\u097F' for ch in word)

def normalize_hindi(word):
    # Keep only Devanagari characters
    word = re.sub(r"[^\u0900-\u097F]", "", word)

    # Always remove trailing visarga
    word = word.rstrip("ः")

    return word

def is_plural_english(word):
    return word.lower().endswith("s") and len(word) > 4

def split_camel_case(word):
    return re.findall(r"[A-Z][a-z]*", word)

def is_bad_short_english(word):
    return len(word) <= 2

def is_acronym(word):
    return word.isupper() and len(word) >= 3

def looks_like_translation(en, hi):
    """
    Returns true if hindi word is likely a semantic translation
    rather than a phonetic transliteration.
    """
    hi_roman = romanize_hi(hi)
    if len(hi_roman) <= 3 and len(en) >= 4:
        return True
    if abs(len(en) - len(hi_roman)) > 4:
        return True
    return False

def is_native_hindi_translation(hi_word):
    """
    Detects short native Hindi words likely to be translations
    rather than transliterations.
    """
    return len(hi_word) <= 3
    
def romanize_hi(word):
    try:
        return transliterate(word, sanscript.DEVANAGARI, sanscript.ITRANS)
    except Exception:
        return ""

def similarity(a,b):
    return SequenceMatcher(None, a.lower(), b.lower()).ratio()

en_file = Path("data/raw/parallel-n/IITB.en-hi.en")
hi_file = Path("data/raw/parallel-n/IITB.en-hi.hi")

en_lines, hi_lines = [], []

with open(en_file, encoding = "utf-8") as f_en, open(hi_file, encoding = "utf-8") as f_hi:
    for i, (en, hi) in enumerate(zip(f_en, f_hi)):
        if i >= MAX_LINES:
            break
        en_lines.append(en.strip())
        hi_lines.append(hi.strip())

print(f"Loaded {len(en_lines)} sentence pairs")

aligned_pairs = set()

for en_sent, hi_sent in zip(en_lines, hi_lines):
    doc = nlp(en_sent)
    title_like = is_title_like(doc)

    en_names = set()

    for ent in doc.ents:
        if ent.label_ in {"PERSON", "ORG", "PRODUCT", "GPE"}:
            en_names.add(ent.text)
    
    for token in doc:
        if (
            token.text[0].isupper()
            and token.is_alpha
            and len(token.text) > 2
            and token.text.lower() not in COMMON_ENGLISH
            and (token.i != 0 or title_like)
        ):
            raw_parts = re.split(r"[\/]", token.text)

            for part in raw_parts:
                camel_parts = split_camel_case(part)
                for p in camel_parts:
                    if p.lower() not in COMMON_ENGLISH and len(p) > 2:
                        en_names.add(p)

    if not en_names:
        continue
        
    # if len(aligned_pairs) == 0:
    #     print("EN SENT: ", en_sent)
    #     print("EN NAMES: ", en_names)
    #     print("HI SENT: ", hi_sent)
    #     print("-" * 50)

    hi_tokens = hi_sent.split()

    
    for en_name in en_names:
        if any(
            part.lower() in SEMANTIC_IDENTIFIER_WORDS
            for part in split_camel_case(en_name)
        ):
            continue

        if en_name.lower() in DIRECTIONAL_ADJECTIVES:
            continue
            
        if en_name.lower() in ENGLISH_DEMONYMS:
            continue
            
        parts = en_name.split()
        if len(parts) > 1 and len(parts[-1]) <= 2:
            continue
            
        if en_name.lower() in {"read", "write", "open", "close", "set", "get"}:
            continue
            
        if is_acronym(en_name) and en_name.lower() not in {"imap", "ldap", "smtp", "http"}:
            continue
            
        if is_bad_short_english(en_name):
            continue
            
        if en_name.lower() in BAD_ENGLISH:
            continue
            
        if en_name.lower() in COMMON_ENGLISH:
            continue

        if en_name.lower() in ENGLISH_DEMONYMS:
            continue

        if is_plural_english(en_name):
            continue

        best_match = None
        best_score = 0.0

        for hi_word in hi_tokens:
            hi_word = normalize_hindi(hi_word)

            if hi_word in {"पथ", "मार्ग", "नाम", "स्थिति", "संख्या"}:
                continue

            if " " in hi_word:
                continue

            if not hi_word:
                continue
                
            # Skip non-Devanagari tokens (e.g., "Search", punctuation)
            if not is_devanagari(hi_word):
                continue
                
            # Skip common Hindi function/translation words
            if hi_word in COMMON_HINDI:
                continue

            if hi_word in DEMONYM_TRANSLATIONS:
                continue

            if len(hi_word) > 15:
                continue
                
            hi_roman = romanize_hi(hi_word)

            if (
                len(hi_word) <= 3
                and similarity(en_name, hi_roman) > 0.8
            ):
                continue

            if looks_like_translation(en_name, hi_word):
                continue

            if len(hi_roman) > len(en_name) * 1.6:
                continue

            if hi_roman in en_name.lower() or en_name.lower() in hi_roman:
                if abs(len(en_name) - len(hi_roman)) > 3:
                    continue
                    
            # Skip weak phonetic matches (not transliterations)
            if similarity(en_name, hi_roman) < 0.6:
                continue
                
            score = similarity(en_name, hi_roman)

            if score > best_score:
                best_score = score
                best_match = hi_word

        if best_score >= SIM_THRESHOLD:
            aligned_pairs.add((
                en_name,
                best_match,
                round(best_score, 3)
            ))

aligned_pairs = list(aligned_pairs)

print("Total aligned pairs: ", len(aligned_pairs))

with open(f"data/processed/aligned_pairs_{OUTPUT_TAG}.json", "w", encoding = "utf-8") as f:
    json.dump(aligned_pairs, f, ensure_ascii = False, indent = 2)

print(f"Saved aligned_pairs_{OUTPUT_TAG}.json")
# Out:
# Loaded 100000 sentence pairs
# Total aligned pairs:  707
# Saved aligned_pairs_100k.json

# %%
aligned_pairs
# Out:
# [('Scoring', 'स्कोरिंग', 0.667),
#  ('Binding', 'बाइंडिंग', 0.625),
#  ('Camera', 'कैमरा', 0.615),
#  ('Radio', 'रेडियो', 0.727),
#  ('Transcode', 'ट्रांसकोड', 0.632),
#  ('Number', 'नंबर', 0.615),
#  ('Hostname', 'होस्टनाम', 0.824),
#  ('Khmer', 'ख्मेर', 0.909),
#  ('Telex', 'टेलेक्स', 0.667),
#  ('Are', 'आगे', 0.667),
#  ('Cellphone', 'सेलफोन', 0.667),
#  ('Farsi', 'फारसी', 0.667),
#  ('Reload', 'रीलोड', 0.667),
#  ('Drive', 'ड्राइव', 0.727),
#  ('Text', 'टेक्स्ट', 0.6),
#  ('Yukon', 'युकान', 0.727),
#  ('Stash', 'सत्र', 0.6),
#  ('Video', 'विडियो', 0.727),
#  ('Trigger', 'ट्रिगर', 0.714),
#  ('America / Rio', 'अमेरिकारियो', 0.75),
#  ('Vitamin', 'विटामिन', 0.933),
#  ('Empathy', 'एंपेथी', 0.714),
#  ('Novell', 'नोवेल', 0.833),
#  ('Credit', 'क्रेडिट', 0.769),
#  ('Valid', 'वैध', 0.727),
#  ('Header', 'हैडर', 0.615),
#  ('Website', 'वेबसाइट', 0.625),
#  ('Install', 'इंस्टाल', 0.714),
#  ('New Project', 'प्रोजेक्ट', 0.632),
#  ('New Menu', 'मेनू', 0.667),
#  ('Retro', 'रीट्रो', 0.8),
#  ('Latvian', 'लटावियन', 0.824),
#  ('Africa / Dakar', 'अफ्रीकाडकार', 0.667),
#  ('Snapshot', 'स्नैपशॉट', 0.7),
#  ('Berkeley', 'बर्कले', 0.667),
#  ('WebKit', 'वेबकिट', 0.714),
#  ('Homepage', 'होमपेज', 0.625),
#  ('Kit', 'कि', 0.8),
#  ('Valid', 'वाली', 0.889),
#  ('Signal', 'सिग्नल', 0.923),
#  ('Pattern', 'पैटर्न', 0.667),
#  ('Tome', 'टोमे', 1.0),
#  ('Regular', 'रेग्युलर', 0.875),
#  ('Processor', 'प्रोसेसर', 0.667),
#  ('Threading', 'थ्रेडिंग', 0.778),
#  ('Aisleriot', 'एस्लेरियॉट', 0.6),
#  ('Inline', 'इनलाइन', 0.714),
#  ('Suite', 'सूट', 0.667),
#  ('Navigator', 'नेविगेटर', 0.632),
#  ('Memory', 'मेमोरी', 0.833),
#  ('Simulation', 'सिमुलेशन', 0.667),
#  ('Europe / Skopje', 'यूरोपस्कोपजे', 0.714),
#  ('Capulet', 'कापुलेट', 0.8),
#  ('Telepathy', 'टेलीपैथी', 0.737),
#  ('Shoot', 'शूट', 0.6),
#  ('Demo', 'डेमो', 1.0),
#  ('Channel', 'चैनल', 0.667),
#  ('Handling', 'हैंडलिंग', 0.632),
#  ('Inheritance', 'इंहेरीटेंस', 0.636),
#  ('Collapse', 'कोलैप्स', 0.625),
#  ('Logo', 'लोगो', 1.0),
#  ('Socket', 'सॉकेट', 0.615),
#  ('Terrace', 'टेरेस', 0.615),
#  ('Loader', 'लोडर', 0.667),
#  ('Flash', 'फ़्लैश', 0.833),
#  ('Africa / Maputo', 'अफ्रीकामपुटो', 0.714),
#  ('Post', 'पोर्ट', 0.667),
#  ('Japan', 'जापान', 0.909),
#  ('Network', 'नेटवर्क', 0.625),
#  ('Burning', 'बर्निंग', 0.667),
#  ('Syne', 'स्याने', 0.889),
#  ('Threshold', 'थ्रेसहोल्ड', 0.9),
#  ('Timeout', 'टाइमआउट', 0.625),
#  ('Link', 'लिंक', 0.667),
#  ('List', 'रीसेट', 0.6),
#  ('Posting', 'पोस्टिंग', 0.8),
#  ('Switch', 'स्विच', 0.667),
#  ('Printed', 'प्रिंटेड', 0.8),
#  ('Romeo', 'रोमियो', 0.727),
#  ('Breakpoint', 'ब्रेकपाइन्ट', 0.762),
#  ('Video', 'वीडियो', 0.727),
#  ('Unicode', 'यूनीकोड', 0.667),
#  ('Monte', 'मोन्ते', 1.0),
#  ('Gaps', 'गैप्स', 0.8),
#  ('America / Iqaluit', 'अमेरिकाइकाल्यूत', 0.688),
#  ('River', 'रिवर', 0.727),
#  ('America / Dominica', 'अमेरिकाडोमिनिका', 0.788),
#  ('Checksum', 'चेकसम', 0.706),
#  ('Pandang', 'पंडांग', 0.667),
#  ('Netmeeting', 'नेटमीटिंग', 0.667),
#  ('Mobile', 'मोबाईल', 0.769),
#  ('Stash', 'स्टैश', 0.833),
#  ('Chatroom', 'चैटरूम', 0.667),
#  ('Unicode', 'यूनिकोड', 0.667),
#  ('Smiley', 'स्माइली', 0.667),
#  ('Registrar', 'रजिस्ट्रार', 0.737),
#  ('Panel', 'पैनल', 0.667),
#  ('Trade', 'ट्रैड', 0.727),
#  ('iCalendar', 'आईकैलेंडर', 0.667),
#  ('Burner', 'बर्नर', 0.615),
#  ('Script', 'स्क्रिप्ट', 0.769),
#  ('America / Mazatlan', 'अमेरिकामजात्लान', 0.765),
#  ('America / Rosario', 'अमेरिकारोसारियो', 0.812),
#  ('Server', 'सर्वर', 0.615),
#  ('Sheet', 'शीट', 0.6),
#  ('Switcher', 'स्विचर', 0.625),
#  ('Carlo', 'कार्लो', 0.8),
#  ('Change', 'चयन', 0.615),
#  ('Africa / Kigali', 'अफ्रीकाकिगाली', 0.714),
#  ('System', 'सिस्टम', 0.615),
#  ('Africa / Khartoum', 'अफ्रीकाखार्टून', 0.625),
#  ('Enumeration', 'एनुमरेशन', 0.609),
#  ('Valgrind', 'वालग्रिंड', 0.778),
#  ('Romanian', 'रोमानियाई', 0.824),
#  ('Gravity', 'ग्रैविटी', 0.8),
#  ('SpamAssassin', 'स्पैमएसेसिन', 0.72),
#  ('Warning', 'वार्निंग', 0.667),
#  ('Ababa', 'अबाबा', 1.0),
#  ('Europe / Kiev', 'यूरोपकीव', 0.609),
#  ('Bugzilla', 'बगजिला', 0.625),
#  ('Aisleriot', 'एस्लेरियाट', 0.632),
#  ('Font', 'फ़ॉन्ट', 0.6),
#  ('Forwarding', 'फ़ॉरवर्डिंग', 0.609),
#  ('Manual', 'मैनुअल', 0.857),
#  ('Second', 'सेकेण्ड', 0.615),
#  ('Project', 'प्रोजेक्ट', 0.8),
#  ('Snippet', 'स्निपेट', 0.857),
#  ('Street', 'स्ट्रीट', 0.667),
#  ('Hold', 'होल्ड', 0.889),
#  ('Caps', 'कैप्स', 0.6),
#  ('vCard', 'कार्ड', 0.6),
#  ('Public', 'पब्लिक', 0.615),
#  ('Visual', 'विजुअल', 0.769),
#  ('Provider', 'प्रोवाइडर', 0.778),
#  ('Directory', 'डिरेक्ट्री', 0.706),
#  ('folder:%', 'फ़ोल्डर', 0.667),
#  ('devanagari', 'देवनागरी', 1.0),
#  ('Calendar', 'चलाना', 0.667),
#  ('Africa / Bamako', 'अफ्रीकाबमाको', 0.714),
#  ('Athena', 'एथेना', 0.833),
#  ('Tutorial', 'ट्यूटोरियल', 0.842),
#  ('Gujarati', 'गुजराती', 1.0),
#  ('Encoding', 'एनकोडिंग', 0.667),
#  ('Database', 'डेटाबेस', 0.625),
#  ('August', 'अगस्त', 0.667),
#  ('SmartCard', 'स्मार्ट', 0.8),
#  ('Greek', 'ग्रीक', 0.6),
#  ('Pidgin', 'पिडगिन', 0.857),
#  ('America / Belize', 'अमेरिकाबेलाइज', 0.667),
#  ('Europe', 'यूरोप', 0.667),
#  ('Balsa', 'बाल्स', 1.0),
#  ('Backend', 'बैकेंड', 0.667),
#  ('Pass', 'पास', 0.75),
#  ('Server', 'सेवा', 0.6),
#  ('Fortran', 'फोर्ट्रान', 0.75),
#  ('Lucia', 'लुसिया', 0.727),
#  ('Telepathy', 'टेलिपाथी', 0.778),
#  ('America / Yakutat', 'अमेरिकायाकुतात', 0.812),
#  ('VCard', 'वीकार्ड', 0.667),
#  ('Phone', 'फोन', 0.8),
#  ('Gnome', 'ग्नोम', 0.8),
#  ('IP Telephony', 'टेलिफोनी', 0.667),
#  ('Velho', 'वेल्हो', 1.0),
#  ('Rating', 'गति', 0.6),
#  ('Follo', 'फोलो', 0.6),
#  ('Fast', 'फास्ट', 0.6),
#  ('Europe / Helsinki', 'यूरोपहेलसिंकी', 0.688),
#  ('List', 'स्लाइस', 0.6),
#  ('Search', 'सही', 0.6),
#  ('Aaiun', 'ऐउन', 0.8),
#  ('PostScript', 'पोस्टस्क्रिप्ट', 0.818),
#  ('Profile', 'प्रोफाइल', 0.625),
#  ('Slideshow', 'स्लाइडशो', 0.778),
#  ('Implementation', 'इम्प्लीमेंटेशन', 0.621),
#  ('Match', 'इंच', 0.6),
#  ('Bogofilter', 'बोगोफिल्टर', 0.727),
#  ('Jabber', 'जैब्बर', 0.714),
#  ('Grid', 'ग्रिड', 0.889),
#  ('Internet', 'इंटरनेट', 0.667),
#  ('Image', 'बिंब', 0.6),
#  ('Vietnamese', 'विएतनामी', 0.737),
#  ('Free', 'करेगे', 0.6),
#  ('Tunneling', 'टनेलिंग', 0.667),
#  ('Kick', 'किक', 0.75),
#  ('Odessa', 'ओडेसा', 0.909),
#  ('America / Eirunepe', 'अमेरिकाएरनेपे', 0.75),
#  ('Africa / Maseru', 'अफ्रीकामसेरु', 0.714),
#  ('Terminal', 'टर्मिनल', 0.824),
#  ('Scan', 'स्कैन', 0.6),
#  ('Indian / Kerguelen', 'इंडियनकेरगुएलेन', 0.757),
#  ('Metadata', 'मेटाडेटा', 0.875),
#  ('June', 'जून', 0.75),
#  ('Gnome', 'गनोम', 0.727),
#  ('Europe / Dublin', 'यूरोपडब्लिन', 0.643),
#  ('Asia / Kamchatka', 'एशियाकमचटका', 0.606),
#  ('Menu', 'मेनू', 1.0),
#  ('Setup', 'सेटअप', 0.667),
#  ('Live', 'लाइव', 0.667),
#  ('Editor', 'एडीटर', 0.769),
#  ('Klondike', 'क्लॉन्डिके', 0.824),
#  ('Save Message', 'संदेश', 0.6),
#  ('Developer', 'डेवलेपर', 0.632),
#  ('Caribou', 'कैरिबो', 0.714),
#  ('Support', 'सपोर्ट', 0.714),
#  ('Apple', 'अपने', 0.6),
#  ('Russian', 'रूसी', 0.727),
#  ('Boston', 'बोस्टन', 0.769),
#  ('Mail', 'फ़ाइल', 0.667),
#  ('Limit', 'सीमित', 0.727),
#  ('America / Maceio', 'अमेरिकामेसीओ', 0.714),
#  ('Make', 'आंकडे', 0.6),
#  ('Print', 'प्रिंट', 0.727),
#  ('Set Bac', 'सेट', 0.727),
#  ('Helsinki', 'हेलसिंकी', 0.824),
#  ('Africa / Malabo', 'अफ्रीकामलाबो', 0.714),
#  ('Romanian', 'रोमानियन', 0.889),
#  ('Java', 'जावा', 1.0),
#  ('Microsoft', 'माइक्रोसॉफ़्ट', 0.667),
#  ('Mouse', 'माउस', 0.6),
#  ('Africa / Dar', 'अफ्रीकादार', 0.609),
#  ('Booth', 'बूथ', 0.6),
#  ('Disk', 'डिस्क', 0.889),
#  ('Metadata', 'मेटाडाटा', 1.0),
#  ('Plugin', 'प्लगइन', 0.714),
#  ('Filtering', 'फिल्टरिंग', 0.6),
#  ('Jump', 'जम्प', 0.667),
#  ('Epiphany', 'एपिफेनी', 0.75),
#  ('America / Edmonton', 'अमेरिकाएडमोंटेन', 0.629),
#  ('GiB', 'गई', 0.667),
#  ('Breakpoint', 'ब्रेकपाइंट', 0.667),
#  ('Photo', 'फोटो', 1.0),
#  ('Italic', 'इटालिक', 0.769),
#  ('Toolbar', 'टूलबार', 0.667),
#  ('Indian / Comoro', 'इंडियनकोमोरो', 0.69),
#  ('Local Mail', 'लोकल', 0.625),
#  ('Howe', 'होवे', 0.75),
#  ('Korean', 'कोरियन', 0.714),
#  ('Dutch', 'डच', 0.6),
#  ('Timeline', 'टाइमलाइन', 0.667),
#  ('Card', 'कार्ड', 0.667),
#  ('Stage', 'स्टेज', 0.6),
#  ('Helena', 'हेलेना', 1.0),
#  ('Alpha', 'अल्फा', 1.0),
#  ('Royal', 'रॉयल', 0.667),
#  ('Ekiga', 'किया', 0.667),
#  ('Graph', 'ग्राफ', 0.909),
#  ('Module', 'मोड', 0.6),
#  ('Basic', 'बाल्सा', 0.6),
#  ('Monospace', 'मोनोस्पेस', 0.778),
#  ('Cairo', 'कैरो', 0.8),
#  ('Greeting', 'ग्रीटिंग', 0.625),
#  ('Estonian', 'एस्टोनियन', 0.889),
#  ('Site', 'साइटें', 0.8),
#  ('Pileon', 'पाइलेअन', 0.714),
#  ('Brasero', 'ब्रैसेरो', 0.933),
#  ('Shader', 'शेडर', 0.615),
#  ('Rica', 'रिका', 0.75),
#  ('Profiler', 'प्रोफाइलर', 0.632),
#  ('Metric', 'मेट्रिक', 0.769),
#  ('Albert', 'अलबर्ट', 0.714),
#  ('Generic', 'ज़ेनेरिक', 0.667),
#  ('Inspector', 'इंस्पेक्टर', 0.632),
#  ('Lumpur', 'लांपुर', 0.769),
#  ('Note', 'होते', 0.75),
#  ('Europe / Tallinn', 'यूरोपटैल्लिन', 0.667),
#  ('Europe / Sarajevo', 'यूरोपसाराजेवो', 0.774),
#  ('Disconnect', 'डिस्कनेक्ट', 0.6),
#  ('Quatorze', 'क्वातोर्जे', 0.625),
#  ('Run Program', 'प्रोग्राम', 0.737),
#  ('What', 'हटा', 0.75),
#  ('Mono', 'मोनो', 1.0),
#  ('New', 'नए', 0.667),
#  ('Launch', 'लॉन्च', 0.769),
#  ('Portrait', 'पोट्रैट', 0.875),
#  ('America / Guadeloupe', 'अमेरिकागुआडेलोप', 0.778),
#  ('Guide', 'गाइड', 0.6),
#  ('Clipboard', 'क्लिपबोर्ड', 0.737),
#  ('Break', 'ब्रेक', 0.8),
#  ('JavaScript', 'जावास्क्रिप्ट', 0.857),
#  ('Clip', 'क्लिप', 0.667),
#  ('Indian / Mayotte', 'इंडियनमयोटे', 0.733),
#  ('Refresh', 'रिफ्रेश', 0.625),
#  ('Balsa', 'बाल्सा', 1.0),
#  ('Treemap', 'ट्रीमैप', 0.667),
#  ('Program', 'प्रोग्राम', 0.933),
#  ('Tick', 'टिक', 0.75),
#  ('Patch', 'पैच', 0.727),
#  ('Novell', 'नॉवेल', 0.615),
#  ('Pidgin', 'पिजिन', 0.667),
#  ('Trust', 'ट्रस्ट', 0.727),
#  ('Helvetica', 'हैलवेटिका', 0.7),
#  ('Bind', 'बाइंड', 0.6),
#  ('Target', 'करे', 0.6),
#  ('Bristol', 'ब्रिस्टल', 0.8),
#  ('America / Vancouver', 'अमेरिकावैंकूवर', 0.611),
#  ('Turk', 'टर्क', 0.667),
#  ('Print', 'प्रिन्ट', 0.909),
#  ('Trash', 'ट्रैश', 0.833),
#  ('Lithuanian', 'लिथानियान', 0.857),
#  ('Adium', 'यदि', 0.667),
#  ('Folder', 'फ़ोल्डरों', 0.714),
#  ('Node', 'नोड', 0.75),
#  ('XVideo', 'वीडियो', 0.667),
#  ('Europe / Andorra', 'यूरोपअंडोरा', 0.643),
#  ('Statement', 'स्टेटमेन्ट', 0.737),
#  ('MacArabic', 'अरबी', 0.714),
#  ('Mask', 'मास्क', 0.889),
#  ('Europe / Uzhgorod', 'यूरोपउझगोरोड', 0.667),
#  ('Transport', 'ट्रांसपोर्ट', 0.8),
#  ('Downloads Bar', 'डाउनलोड्स', 0.609),
#  ('Journal', 'जर्नल', 0.714),
#  ('Tint', 'टिंट', 0.667),
#  ('Phrase', 'फ्रेज', 0.667),
#  ('Salvador', 'सल्वाडोर', 0.941),
#  ('Same', 'समान', 0.6),
#  ('Alarm', 'एलार्म', 0.727),
#  ('Overburn', 'ओवरबर्न', 0.667),
#  ('Africa / Sao', 'अफ्रीकासाओ', 0.636),
#  ('Europe / Stockholm', 'यूरोपस्टाकहोम', 0.606),
#  ('Stop Program', 'प्रोग्राम', 0.7),
#  ('Spider', 'स्पाइडर', 0.714),
#  ('Autowrap', 'आटोव्रेप', 0.625),
#  ('Whitehead', 'व्हाइटहेड', 0.632),
#  ('Europe / Oslo', 'यूरोपओस्लो', 0.696),
#  ('Input', 'इनपुट', 0.833),
#  ('Anjuta', 'हटा', 0.6),
#  ('Object', 'आब्जेक्ट', 0.615),
#  ('Subscribe', 'सब्सक्राईब', 0.6),
#  ('Startup', 'स्टार्टअप', 0.75),
#  ('Wallpaper', 'वॉलपेपर', 0.6),
#  ('Vista', 'विस्टा', 1.0),
#  ('Calendar', 'कैलेन्डर', 0.778),
#  ('April', 'अप्रैल', 0.833),
#  ('Tone', 'टोन', 0.75),
#  ('Note', 'नोट', 0.75),
#  ('Valgrind', 'वेलग्रिंड', 0.667),
#  ('Registry', 'रजिस्ट्री', 0.625),
#  ('Nordic', 'नोर्डिक', 0.769),
#  ('Marino', 'मेरिनो', 0.833),
#  ('Wisp', 'विस्प', 0.667),
#  ('Salut', 'सैलेट', 0.667),
#  ('Mail', 'ऊंचाई', 0.6),
#  ('Minute', 'मिनट', 0.667),
#  ('Kernel', 'कर्नेल', 0.769),
#  ('Indentation', 'इंडेन्टेशन', 0.609),
#  ('America / Tijuana', 'अमेरिकातिजुआना', 0.839),
#  ('Tags', 'टैग्स', 0.8),
#  ('Armenian', 'आर्मेनियाई', 0.824),
#  ('IMAP', 'रिमोट', 0.6),
#  ('Linker', 'लिंकर', 0.615),
#  ('Spool', 'स्पूल', 0.6),
#  ('Korean', 'कोरियाई', 0.615),
#  ('Trace', 'ट्रेस', 0.6),
#  ('Arabic', 'अरेबिक', 0.615),
#  ('Audio', 'ऑडियो', 0.6),
#  ('Palm', 'पाम', 0.75),
#  ('Brazilian', 'ब्राजिलियन', 0.8),
#  ('Resume', 'रिस्यूम', 0.615),
#  ('Many', 'मानते', 0.6),
#  ('Markup', 'मार्कअप', 0.714),
#  ('Serif', 'सेरिफ़', 0.909),
#  ('Chat', 'चैट', 0.8),
#  ('Domain', 'डोमेन', 0.667),
#  ('Tabs', 'टैब्स', 0.8),
#  ('Player', 'प्लेयर', 0.615),
#  ('Caribou', 'कैरिबू', 0.714),
#  ('Branco', 'ब्रैंको', 0.615),
#  ('Backing', 'बैकिंग', 0.667),
#  ('Children', 'चिल्ड्रन', 0.824),
#  ('Please', 'आपसे', 0.727),
#  ('Europe / Gibraltar', 'यूरोपजिब्राल्टर', 0.706),
#  ('MacGujarati', 'गुजराती', 0.842),
#  ('Apache', 'अपाचे', 1.0),
#  ('America / Cayman', 'अमेरिकाकेमन', 0.621),
#  ('Database', 'डाटाबेस', 0.75),
#  ('Object', 'ऑब्जेक्ट', 0.615),
#  ('Africa / Harare', 'अफ्रीकाहरारे', 0.714),
#  ('Burner', 'ब्रेसेरो', 0.615),
#  ('Tabs', 'टेब्स', 0.667),
#  ('Bengali', 'बंगाली', 0.714),
#  ('Groupware', 'ग्रूपवेयर', 0.6),
#  ('Africa / Kampala', 'अफ्रीकाकंपाला', 0.733),
#  ('Descriptive', 'डिस्क्रिप्टिव', 0.727),
#  ('Africa / Nairobi', 'अफ्रीकानैरोबी', 0.733),
#  ('Prompt', 'प्रांप्ट', 0.769),
#  ('Dasher', 'डैशर', 0.714),
#  ('Talk', 'टॉक', 0.667),
#  ('America / Nassau', 'अमेरिकानासाऊ', 0.786),
#  ('Pango', 'पैंगो', 0.727),
#  ('Paste', 'पाठ', 0.6),
#  ('Gurmukhi (Mac', 'गुरूमुखी', 0.727),
#  ('Timestamp', 'टाइमस्टैंप', 0.762),
#  ('Please', 'पास', 0.6),
#  ('Tarball', 'टारबाल', 0.8),
#  ('Tracking', 'ट्रैकिंग', 0.706),
#  ('Scroll', 'स्क्रोल', 0.667),
#  ('Saratoga', 'साराटोगा', 1.0),
#  ('Africa / Mbabane', 'अफ्रीकाम्बाबने', 0.733),
#  ('Africa / Nouakchott', 'अफ्रीकानुआकचोट', 0.667),
#  ('Caret', 'कैरेट', 0.667),
#  ('Africa / Asmera', 'अफ्रीकाअस्मेरा', 0.714),
#  ('Africa / Timbuktu', 'अफ्रीकाटिम्बकटू', 0.667),
#  ('VCard', 'कार्ड', 0.6),
#  ('Stash', 'संदेश', 0.615),
#  ('Auld', 'अल्ड', 0.75),
#  ('Plugin', 'प्लगिन', 0.769),
#  ('Delivery', 'डिलिवरी', 0.625),
#  ('Spatial', 'स्पासियल', 0.75),
#  ('America / Martinique', 'अमेरिकामारटीनिक', 0.703),
#  ('Model', 'मोड', 0.667),
#  ('Asia / Dushanbe', 'एशियादुशान्बे', 0.621),
#  ('America / Belem', 'अमेरिकाबेलम', 0.714),
#  ('Make', 'सकेगा', 0.6),
#  ('Remote', 'रिमोट', 0.667),
#  ('Juliet', 'जुलियट', 0.714),
#  ('Burst', 'बर्स्ट', 0.727),
#  ('Sieve', 'सीव', 0.667),
#  ('Developer', 'डेवलपर', 0.632),
#  ('Mozilla', 'मोज़िला', 0.923),
#  ('Alt', 'आल्ट', 0.857),
#  ('Layout', 'लेआउट', 0.667),
#  ('Africa / Douala', 'अफ्रीकाडोउला', 0.667),
#  ('Filtering', 'फ़िल्टर', 0.625),
#  ('Tracing', 'ट्रैस', 0.615),
#  ('Field', 'फ़ील्ड', 0.8),
#  ('Atlantic / Bermuda', 'एटलांटिकबरमुडा', 0.611),
#  ('Imperial', 'इंपीरियल', 0.778),
#  ('Generic', 'जेनेरिक', 0.667),
#  ('Europe / Budapest', 'यूरोपबुडापेस्ट', 0.75),
#  ('Touch', 'टच', 0.6),
#  ('Suit', 'सूट', 0.75),
#  ('Filename', 'फ़ाइलनाम', 0.706),
#  ('Exchange', 'पूछने', 0.667),
#  ('Protocol', 'प्रोटोकाल', 0.706),
#  ('Celtic', 'सेल्टिक', 0.615),
#  ('Simplified', 'सिम्लिफाइड', 0.667),
#  ('Modem', 'मॉडेम', 0.667),
#  ('Short', 'छोटा', 0.6),
#  ('Gaps', 'गैप', 0.667),
#  ('Thread', 'पीथ्रेड्स', 0.667),
#  ('Scope', 'स्कोप', 0.6),
#  ('Header', 'हेडर', 0.667),
#  ('Recorder', 'रेकोर्डर', 0.706),
#  ('Setter', 'सेटर', 0.667),
#  ('Serial', 'सीरियल', 0.714),
#  ('Trash', 'ट्रेश', 0.727),
#  ('America / Nome', 'अमेरिकानोम', 0.72),
#  ('Quit Brasero', 'ब्रैसेरो', 0.7),
#  ('Penh', 'पेन्ह', 0.889),
#  ('Vala', 'वाला', 1.0),
#  ('Fahrenheit', 'फॉरेनहाइट', 0.609),
#  ('Hill', 'हिल', 0.75),
#  ('Devhelp', 'डेवहेल्प', 0.875),
#  ('Europe / Madrid', 'यूरोपमैड्रिड', 0.69),
#  ('Yahoo', 'याहू', 0.667),
#  ('Weblog', 'वेब्लाग', 0.615),
#  ('Click', 'क्लिक', 0.6),
#  ('Europe / Chisinau', 'यूरोपचिसिनाउ', 0.774),
#  ('America / Miquelon', 'अमेरिकामिक्वेलन', 0.647),
#  ('Monitor', 'मॉनीटर', 0.625),
#  ('Draft', 'ड्राफ्ट', 0.667),
#  ('Simulate', 'सिमुलेट', 0.75),
#  ('Building', 'बिल्डिंग', 0.75),
#  ('Epiphany', 'एपिफैनी', 0.824),
#  ('America / Juneau', 'अमेरिकाजुनेऊ', 0.786),
#  ('America / Menominee', 'अमेरिकामेनोमिनी', 0.765),
#  ('Anjuta', 'अंजुता', 0.833),
#  ('Underline', 'अण्डरलाइन', 0.6),
#  ('Shelf', 'शेल्फ', 0.667),
#  ('Epiphany', 'एपीफेनी', 0.75),
#  ('Blog', 'ब्लॉग', 0.6),
#  ('Flash', 'फ्लैश', 0.615),
#  ('Hang', 'हैंग', 0.6),
#  ('Traditional', 'ट्रेडिशनल', 0.609),
#  ('Danish', 'दानिश', 0.923),
#  ('Aspect', 'आस्पेक्ट', 0.769),
#  ('Polish', 'पालिश', 0.769),
#  ('Menu', 'मेन्यू', 0.889),
#  ('Macro', 'मेक्रो', 0.6),
#  ('Load', 'लोड', 0.75),
#  ('Russian', 'रसियन', 0.667),
#  ('Glade', 'ग्लेड', 0.6),
#  ('Ekiga', 'एकिगा', 1.0),
#  ('Restore', 'रिस्टोर', 0.714),
#  ('Overcast', 'ओवरकास्ट', 0.667),
#  ('Lisp', 'लिप्स', 0.667),
#  ('Editor', 'एडिटर', 0.769),
#  ('Balsa', 'बल्सा', 1.0),
#  ('Pilot', 'पाइलट', 0.667),
#  ('Combo', 'कोंबो', 0.8),
#  ('Phrase', 'फ्रेस', 0.667),
#  ('Back', 'बैक', 0.667),
#  ('Africa / Bujumbura', 'अफ्रीकाबुजुंबरा', 0.706),
#  ('Rico', 'रिको', 0.75),
#  ('Europe / Warsaw', 'यूरोपवार्सा', 0.615),
#  ('Ukrainian', 'यूक्रेनियन', 0.7),
#  ('Block', 'ब्लाक', 0.6),
#  ('Loaded', 'लोड', 0.6),
#  ('Spain', 'स्पेन', 0.6),
#  ('Algorithm', 'एलागरिथम', 0.667),
#  ('Profiling', 'प्रोफाईलिंग', 0.667),
#  ('Media', 'मीडिया', 0.727),
#  ('Disconnected', 'डिस्कनेक्टेड', 0.667),
#  ('Megaphone', 'मेगाफोन', 0.889),
#  ('Europe / Zagreb', 'यूरोपजैग्रेब', 0.621),
#  ('Image', 'इमेज', 0.6),
#  ('Django', 'जैंगो', 0.667),
#  ('What', 'खाता', 0.667),
#  ('Slovak', 'स्लोवाक', 0.923),
#  ('January', 'जनवरी', 0.667),
#  ('Theme', 'थीम', 0.6),
#  ('Europe / Simferopol', 'यूरोपसिंफेरोपोल', 0.703),
#  ('Login', 'लॉगिन', 0.667),
#  ('Smart', 'स्मार्ट', 0.909),
#  ('Margin', 'मार्जिन', 0.769),
#  ('Europe / Riga', 'यूरोपरीगा', 0.696),
#  ('Buddy', 'बड्डी', 0.6),
#  ('Europe / Bucharest', 'यूरोपबुखारेस्ट', 0.706),
#  ('Chart', 'चार्ट', 0.909),
#  ('Calendar', 'कैलेंडर', 0.667),
#  ('Its', 'इस', 0.667),
#  ('America / Swift', 'अमेरिकास्विफ्ट', 0.621),
#  ('Item', 'हटाएं', 0.6),
#  ('Pine', 'पीछे', 0.667),
#  ('Stream', 'स्ट्रीम', 0.667),
#  ('Drag', 'ड्रैग', 0.8),
#  ('Europe / Rome', 'यूरोपरोम', 0.609),
#  ('May', 'मई', 0.667),
#  ('Host', 'होस्ट', 0.889),
#  ('Tracking', 'ट्रेकिंग', 0.625),
#  ('Telephony', 'टेलिफोनी', 0.778),
#  ('Ringing', 'रिंगिंग', 0.667),
#  ('Realm', 'रीयल्म', 0.667),
#  ('Balsa', 'वाला', 0.667),
#  ('Repository', 'रेपोसिटरी', 0.8),
#  ('Validity', 'वैधता', 0.625),
#  ('Africa / Gaborone', 'अफ्रीकागैब्रोन', 0.625),
#  ('Africa / Abidjan', 'अफ्रीकाआबिदजान', 0.688),
#  ('Desktop', 'डेस्कटॉप', 0.706),
#  ('With', 'तिथि', 0.667),
#  ('Pspell', 'पिक्सेल', 0.615),
#  ('Europe / Nicosia', 'यूरोपनिकोसिया', 0.667),
#  ('Europe / Tirane', 'यूरोपटिराने', 0.741),
#  ('Maya', 'माया', 1.0),
#  ('Share', 'साझा', 0.6),
#  ('Jabber', 'जैबर', 0.615),
#  ('Anjuta', 'अंजूटा', 0.833),
#  ('Gamma', 'गामा', 0.889),
#  ('Fit', 'फ़िट', 0.857),
#  ('Temporal', 'टेंपोरल', 0.941),
#  ('Template', 'टेम्पलेट', 0.706),
#  ('Launch%', 'लांच', 0.615),
#  ('Line', 'लाइन', 0.667),
#  ('Domingo', 'डोमिन्गो', 1.0),
#  ('Monitor', 'मानिटर', 0.667),
#  ('Pascal', 'पास्कल', 0.769),
#  ('Anjuta', 'अंजुटा', 0.833),
#  ('Pago', 'पैगो', 0.889),
#  ('Bear', 'बीयर', 0.6),
#  ('Preset', 'प्रीसेट', 0.769),
#  ('Africa / Lusaka', 'अफ्रीकालुसाका', 0.714),
#  ('Post', 'पोस्ट', 0.889),
#  ('Scala', 'स्केल', 0.6),
#  ('Role', 'रोल', 0.75),
#  ('Bison', 'बाइसन', 0.667),
#  ('Europe / Zaporozhye', 'यूरोपजैपोरोझाए', 0.611),
#  ('Hello', 'हेलो', 0.889),
#  ('Encode', 'एन्कोड', 0.667),
#  ('Macro', 'मैक्रो', 0.727),
#  ('Bookmark', 'बुकमार्क', 0.706),
#  ('Python', 'पायथन', 0.667),
#  ('Image', 'इमेज़', 0.6),
#  ('Interpolate', 'इंटरपोलेट', 0.609),
#  ('Golf', 'गोल्फ', 0.6),
#  ('Hindi', 'हिन्दी', 1.0),
#  ('Home', 'होम', 0.75),
#  ('Shell', 'शेल', 0.8),
#  ('Border', 'बार्डर', 0.615),
#  ('Postpone', 'पोस्टपोन', 0.824),
#  ('Epiphany', 'एपीफैनी', 0.824),
#  ('Kernel', 'कर्नल', 0.615),
#  ('Site', 'साइट', 0.667),
#  ('Library', 'लाइब्रेरी', 0.667),
#  ('Africa / Banjul', 'अफ्रीकाबांजुल', 0.621),
#  ('AisleRiot', 'एसलिरियोट', 0.6),
#  ('Unset', 'अनसेट', 0.667),
#  ('Content', 'कॉन्टेन्ट', 0.625),
#  ('Europe / Vaduz', 'यूरोपवाडुज', 0.615),
#  ('Ethiopic', 'इथिइयोपिक', 0.632),
#  ('Africa / Bissau', 'अफ्रीकाबिस्साओ', 0.643),
#  ('Drag Threshold', 'थ्रेशोल्ड', 0.75),
#  ('Folder', 'फ़ोल्डर', 0.769),
#  ('Signora', 'सिन्योर', 0.857),
#  ('Port', 'पोर्ट', 0.889),
#  ('Crash', 'क्रैश', 0.667),
#  ('Start', 'स्टार्ट', 0.909),
#  ('Devanagari', 'देवनागरी', 1.0),
#  ('Regular', 'रेगुलर', 0.933),
#  ('Code', 'मोड़ें', 0.6),
#  ('Pine', 'पाइन', 0.667),
#  ('Window', 'विन्डो', 0.727),
#  ('Verde', 'वर्डे', 0.8),
#  ('Bonobo', 'बोनोबो', 1.0),
#  ('AisleRiot', 'एस्लेरियॉट', 0.6),
#  ('Perl', 'पर्ल', 0.667),
#  ('Profile', 'प्रोफ़ाइल', 0.8),
#  ('String', 'स्ट्रिंग', 0.769),
#  ('JHBuild', 'बिल्ड', 0.667),
#  ('Pulseaudio', 'पल्सऑडियो', 0.7),
#  ('Tile', 'टाइल', 0.667),
#  ('Batch', 'बैच', 0.727),
#  ('Hinting', 'हिंटिंग', 0.667),
#  ('America / Adak', 'अमेरिकाअडक', 0.769),
#  ('Finnish', 'फिनिश', 0.667),
#  ('Poker', 'पोकर', 0.727),
#  ('Score', 'स्कोर', 0.6),
#  ('Europe / Lisbon', 'यूरोपलिस्बन', 0.643),
#  ('Presentation', 'प्रस्तुति', 0.6),
#  ('Fragment', 'फ्रैगमेंट', 0.6),
#  ('Module', 'मोड्यूल', 0.769),
#  ('July', 'जुलाई', 0.667),
#  ('Africa / Kinshasa', 'अफ्रीकाकिंशासा', 0.688),
#  ('Avatar', 'अवतार', 0.923),
#  ('Saturation', 'संतृप्ति', 0.6),
#  ('Step', 'स्टेप', 0.889),
#  ('Zebra', 'जेब्रा', 0.8),
#  ('Mobile', 'मोबाइल', 0.769),
#  ('Click', 'लिंक', 0.6),
#  ('Arabic', 'अरबी', 0.909),
#  ('SpamAssassin', 'स्पैमएस्सेसिन', 0.769),
#  ('Profiling', 'प्रोफाइलिंग', 0.667),
#  ('Gadu - Gadu', 'गाडूगाडू', 0.842),
#  ('vCard', 'वीकार्ड', 0.667),
#  ('America / Chihuahua', 'अमेरिकाचिहुआहुआ', 0.857),
#  ('Build', 'बिल्ड', 0.8),
#  ('Fingerprint', 'फ़िंगरप्रिंट', 0.667),
#  ('Marshaller', 'मार्शलर', 0.8),
#  ('Solitaire', 'सॉलिटेयर', 0.6),
#  ('Manager', 'मैनेजर', 0.625),
#  ('ASUrl', 'और', 0.667),
#  ('Europe / Berlin', 'यूरोपबर्लिन', 0.643),
#  ('Talk', 'टाक', 0.75),
#  ('Easthaven', 'ईस्टहैवन', 0.6),
#  ('Ukrainian', 'युकेरियन', 0.632),
#  ('Track', 'ट्रैक', 0.727),
#  ('Automatic', 'आटोमेटिक', 0.667),
#  ('IMAP', 'मैप', 0.667),
#  ('Tamil', 'तमिल', 0.909),
#  ('Mirror', 'मिरर', 0.667),
#  ('Swedish', 'स्वीडिश', 0.667),
#  ('Isabel', 'इसाबेल', 0.923),
#  ('Threshold', 'थ्रेशोल्ड', 0.947),
#  ('Malayalam', 'मलयालम', 0.947),
#  ('Launch', 'लांच', 0.667),
#  ('Login', 'लागिन', 0.727),
#  ('Pipe', 'पाइप', 0.667),
#  ('See', 'इसे', 0.667),
#  ('March', 'मार्च', 0.909),
#  ('Fast Start', 'स्टार्ट', 0.625),
#  ('Evolution', 'एवोल्यूशन', 0.6),
#  ('Once', 'होने', 0.75),
#  ('Tabs', 'टैब', 0.667),
#  ('Protocol', 'प्रोटोकॉल', 0.667),
#  ('York', 'यार्क', 0.667),
#  ('Brasero', 'ब्रेसेरो', 0.857),
#  ('MacRomanian', 'रोमानियाई', 0.7),
#  ('Profiling Data', 'प्रोफाईलिंग', 0.615),
#  ('Marker', 'मार्कर', 0.769),
#  ('Moresby', 'मोरेसबी', 0.8),
#  ('node', 'नोड', 0.75),
#  ('Valentine', 'वेलेंटाइन', 0.632),
#  ('Inlet', 'इनलेट', 0.833),
#  ('Salaam', 'सलाम', 0.833),
#  ('Paulo', 'पोलो', 0.667),
#  ('Patch', 'पैचेस', 0.615),
#  ('Filter', 'फ़िल्टर', 0.769),
#  ('America / Noronha', 'अमेरिकानोरोन्हा', 0.839),
#  ('Italic', 'ईटैलिक', 0.714),
#  ('Audio', 'आडियो', 0.8),
#  ('Import', 'इंपोर्ट', 0.923),
#  ('Telephone', 'टेलिफोन', 0.778),
#  ('Validation', 'वैधता', 0.667),
#  ('Output', 'आउटपुट', 0.714),
#  ('Store', 'स्टोर', 0.8),
#  ('Africa / Luanda', 'अफ्रीकालुआंडा', 0.643),
#  ('Sensitive', 'सेंसिटिव', 0.778),
#  ('Hula', 'हुला', 1.0),
#  ('Slicing', 'स्लाइसिंग', 0.625),
#  ('Microphone', 'माइक्रोफोन', 0.762),
#  ('Europe / Vatican', 'यूरोपवेटिकन', 0.6),
#  ('Delegate', 'डेलिगेट', 0.625),
#  ('License', 'लाइसेन्स', 0.667),
#  ('Nordic', 'नोरडिक', 0.714),
#  ('Jump', 'जंप', 0.667),
#  ('Disc', 'डिस्क', 0.667),
#  ('Europe / Malta', 'यूरोपमाल्टा', 0.72),
#  ('Span', 'स्पैन', 0.8),
#  ('Final', 'फाइनल', 0.615),
#  ('Pixel', 'पिक्सेल', 0.667),
#  ('Aisleriot', 'एसलिरियोट', 0.6),
#  ('Sidebar', 'साइडबार', 0.75),
#  ('Gurmukhi', 'गुरूमुखी', 0.941),
#  ('Reload', 'लोड', 0.6),
#  ('Tags', 'टैग', 0.667),
#  ('Outgoing', 'आउटगोइंग', 0.667),
#  ('Quota', 'कोटा', 0.667),
#  ('Africa / Conakry', 'अफ्रीकाकोनाक्री', 0.6)]

# %%
import json
from collections import Counter

with open("data/processed/aligned_pairs_100k.json", encoding = "utf-8") as f:
    pairs = json.load(f)

english_names = [en for en, _, _ in pairs]

print("Total aligned pairs: ", len(pairs))
print("Unique English Names: ", len(set(english_names)))

print("\nTop 10 most frequent English names:")
for name, count in Counter(english_names).most_common(10):
    print(name, count)
# Out:
# Total aligned pairs:  707
# Unique English Names:  616
#
# Top 10 most frequent English names:
# Balsa 4
# Epiphany 4
# Anjuta 4
# Stash 3
# Aisleriot 3
# Calendar 3
# Image 3
# Tabs 3
# Reload 2
# Video 2

# %%
#LOAD ALIGNED PAIRS AND GROUP BY ENGLISH NAMES

# %%
import json
from collections import defaultdict

with open("data/processed/aligned_pairs_100k.json", encoding = "utf-8") as f:
    aligned_pairs = json.load(f)

name_groups = defaultdict(list)

for en, hi, score in aligned_pairs:
    clean_en = en.strip()
    if "/" in clean_en:
        continue
    name_groups[clean_en].append(hi)

print(f"Total unique English names: {len(name_groups)}")
# Out:
# Total unique English names: 531

# %%
#ROMANIZE HINDI VARIANTS

# %%
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate

def romanize_hi(word):
    try:
        return transliterate(word, sanscript.DEVANAGARI, sanscript.ITRANS)
    except:
        return ""

# %%
#CLUSTER HINDI VARIANTS

# %%
from difflib import SequenceMatcher

def similarity(a,b):
    return SequenceMatcher(None, a.lower(), b.lower()).ratio()

def cluster_variants(hi_variants, threshold = 0.7):
    clusters = []

    for word in hi_variants:
        roman = romanize_hi(word)
        placed = False

        for cluster in clusters:
            rep_roman = cluster["roman"]
            if similarity(roman, rep_roman) >= threshold:
                cluster["variants"].append(word)
                placed = True
                break

        if not placed:
            clusters.append({
                "canonical": word,
                "roman": roman,
                "variants": [word]
            })
    return clusters

# %%
#APPLY CLUSTERING TO ALL NAMES

# %%
BAD_ENGLISH = {
    "this", "that", "these", "those", 
    "data", "report", "name", "set",
    "get", "add", "remove"
}

# %%
BAD_ENGLISH.update({
    "american", "fast", "slow", "new", "old", "good", "bad",
    "open", "close", "high", "low", "western", "eastern", 
    "northern", "southern", "central", "global", "local"
})

# %%
def looks_like_translation(en, hi):
    """
    Returns true if hindi word is likely a semantic translation
    rather than a phonetic transliteration.
    """
    hi_roman = romanize_hi(hi)
    if len(hi_roman) <= 3 and len(en) >= 4:
        return True
    if abs(len(en) - len(hi_roman)) > 4:
        return True
    return False

def is_native_hindi_translation(hi_word):
    """
    Detects short native Hindi words likely to be translations
    rather than transliterations.
    """
    return len(hi_word) <= 3

# %%
canonical_clusters = {}

for en_name, hi_variants in name_groups.items():

    # Clean & normalize
    unique_variants = list(
        set(normalize_hindi(v) for v in hi_variants if normalize_hindi(v))
    )

    if not unique_variants:
        continue

    clusters = cluster_variants(unique_variants)
    final_clusters = []

    for cluster in clusters:
        variants = cluster["variants"]

        # Step 1: remove clear translations early
        phonetic_variants = [
            v for v in variants
            if similarity(en_name, romanize_hi(v)) >= 0.65
            and not looks_like_translation(en_name, v)
            and not is_native_hindi_translation(v)
        ]

        # Step 2: fallback ONLY if nothing survived
        if phonetic_variants:
            candidates = phonetic_variants
        else:
            candidates = sorted(
                variants,
                key=lambda v: similarity(en_name, romanize_hi(v)),
                reverse=True
            )[:1]

        # Step 3: choose canonical
        canonical = min(
            candidates,
            key=lambda v: (
                -similarity(en_name, romanize_hi(v)),
                len(v)
            )
        )

        final_clusters.append({
            "canonical": canonical,
            "variants": variants
        })
        
    if not final_clusters:
        continue
        
    canonical_clusters[en_name] = final_clusters

# %%
#RESULTS

# %%
for en, clusters in list(canonical_clusters.items())[:5]:
    print(f"\n English Name: {en}")
    for c in clusters:
        print("  Canonical:", c["canonical"])
        print("  Variants:", c["variants"])
# Out:
#  English Name: Scoring
#   Canonical: स्कोरिंग
#   Variants: ['स्कोरिंग']
#
#  English Name: Binding
#   Canonical: बाइंडिंग
#   Variants: ['बाइंडिंग']
#
#  English Name: Camera
#   Canonical: कैमरा
#   Variants: ['कैमरा']
#
#  English Name: Radio
#   Canonical: रेडियो
#   Variants: ['रेडियो']
#
#  English Name: Transcode
#   Canonical: ट्रांसकोड
#   Variants: ['ट्रांसकोड']
