# %%
from pathlib import Path

# %%
data_path = Path("data/raw/parallel-n")
files = list(data_path.glob("*"))[:5]
files
# Out:
# [PosixPath('data/raw/parallel-n/IITB.en-hi.en'),
#  PosixPath('data/raw/parallel-n/IITB.en-hi.hi')]

# %%
en_file = "data/raw/parallel-n/IITB.en-hi.en"
hi_file = "data/raw/parallel-n/IITB.en-hi.hi"

with open(en_file, encoding = "utf-8") as f_en, open(hi_file, encoding = "utf-8") as f_hi:
    for i in range(10):
        en_line = f_en.readline().strip()
        hi_line = f_hi.readline().strip()
        print(f"{i+1}. EN: {en_line}")
        print(f"   HI: {hi_line}")
        print("-" * 50)
# Out:
# 1. EN: Give your application an accessibility workout
#    HI: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# --------------------------------------------------
# 2. EN: Accerciser Accessibility Explorer
#    HI: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# --------------------------------------------------
# 3. EN: The default plugin layout for the bottom panel
#    HI: निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# --------------------------------------------------
# 4. EN: The default plugin layout for the top panel
#    HI: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# --------------------------------------------------
# 5. EN: A list of plugins that are disabled by default
#    HI: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# --------------------------------------------------
# 6. EN: Highlight duration
#    HI: अवधि को हाइलाइट रकें
# --------------------------------------------------
# 7. EN: The duration of the highlight box when selecting accessible nodes
#    HI: पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# --------------------------------------------------
# 8. EN: Highlight border color
#    HI: सीमांत (बोर्डर) के रंग को हाइलाइट करें
# --------------------------------------------------
# 9. EN: The color and opacity of the highlight border.
#    HI: हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# --------------------------------------------------
# 10. EN: Highlight fill color
#    HI: भराई के रंग को हाइलाइट करें
# --------------------------------------------------

# %%
import spacy

# %%
#NER ALONE DIDN'T WORK

# %%
nlp = spacy.load("en_core_web_sm")
sentence = "Accerciser Accessibility Explorer"
doc = nlp(sentence)
for ent in doc.ents:
    print(ent.text, ent.label_)

# %%
#COMBINING NER AND HEURISTICS (HYBRID)

# %%
# Load English NLP pipeline
nlp = spacy.load("en_core_web_sm", disable = ["parser", "tagger", "lemmatizer"])

en_file = Path("data/raw/parallel-n/IITB.en-hi.en")

extracted_names = set()

MAX_LINES = 10000

with open(en_file, encoding="utf-8") as f:
    lines = []
    for i, line in enumerate(f):
        if i >= MAX_LINES:
            break
        line = line.strip()
        if line:
            lines.append(line)

print(f"Processing {len(lines)} sentences...")

# Process in batches
for doc in nlp.pipe(lines, batch_size = 500):
    # Part 1: NER
    for ent in doc.ents:
        if ent.label_ in {"PERSON", "ORG", "PRODUCT", "GPE"}:
            extracted_names.add(ent.text)

    # Part 2: Heuristics
    for token in doc:
        if(
            token.text[0].isupper() and
            token.is_alpha and
            len(token.text) > 2
        ):
            extracted_names.add(token.text)

print("Done")
print("Total extracted names: ", len(extracted_names))
list(extracted_names)[:20]
# Out:
# Processing 10000 sentences...
# Done
# Total extracted names:  1227
# ['Alpha',
#  'Run / Continue',
#  'Tommy',
#  'Goto Line',
#  'Freecell',
#  'Loading',
#  'High',
#  'Java',
#  'CVS Options',
#  'Are',
#  'Carlo',
#  'Traditional',
#  'Urgent',
#  'Load Log',
#  'Royal East',
#  'Anjuta',
#  'Four',
#  'Direction',
#  'SymbolDb',
#  'Shell Script File']

# %%
import json

with open("data/processed/extracted_names_en_10k.json", "w", encoding = "utf-8") as f:
    json.dump(sorted(extracted_names), f, ensure_ascii = False, indent = 2)

# %%
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate
from difflib import SequenceMatcher

# %%
nlp = spacy.load("en_core_web_sm", disable=["parser", "tagger", "lemmatizer"])

def romanize_hi(word):
    return transliterate(word, sanscript.DEVANAGARI, sanscript.ITRANS)

def similarity(a,b):
    return SequenceMatcher(None, a.lower(), b.lower()).ratio()

en_file = Path("data/raw/parallel-n/IITB.en-hi.en")
hi_file = Path("data/raw/parallel-n/IITB.en-hi.hi")

MAX_LINES = 10000

en_lines, hi_lines = [], []

with open(en_file, encoding = "utf-8") as f_en , open(hi_file, encoding = "utf-8") as f_hi:
    for i, (en, hi) in enumerate(zip(f_en, f_hi)):
        if i >= MAX_LINES:
            break
        en_lines.append(en.strip())
        hi_lines.append(hi.strip())

aligned_pairs = []

for en_sent, hi_sent in zip(en_lines, hi_lines):
    doc = nlp(en_sent)

    en_names = set()

    for ent in doc.ents:
        if ent.label_ in {"PERSON", "ORG", "PRODUCT", "GPE"}:
            en_names.add(ent.text)

    for token in doc:
        if token.text[0].isupper() and token.is_alpha and len(token.text) > 2:
            en_names.add(token.text)

    if not en_names:
        continue

    hi_tokens = hi_sent.split()

    for en_name in en_names:
        best_match = None
        best_score = 0.0

        for hi_word in hi_tokens:
            if len(hi_word) < 2:
                continue

            hi_roman = romanize_hi(hi_word)
            score = similarity(en_name, hi_roman)

            if score > best_score:
                best_score = score
                best_match = hi_word

        if best_score >= 0.45:
            aligned_pairs.append((en_name, best_match, best_score))

for pair in aligned_pairs[:20]:
    print(pair)
# Out:
# ('Highlight', 'हाइलाइट', 0.5882352941176471)
# ('Highlight', 'हाइलाइट', 0.5882352941176471)
# ('Highlight', 'हाइलाइट', 0.5882352941176471)
# ('API', 'एपीआई', 0.5)
# ('Hide', 'छिपाएं', 0.5454545454545454)
# ('IPython', 'आईपाइथन', 0.5882352941176471)
# ('Console', 'कन्सोल', 0.5714285714285714)
# ('Monitor', 'मानिटर', 0.6666666666666666)
# ('Monitor', 'मानिटर', 0.6666666666666666)
# ('Highlight', 'हाइलाइट', 0.5882352941176471)
# ('WIDGET', 'विडजेट', 0.5714285714285714)
# ('Alpha', 'अल्फा', 1.0)
# ('Des', 'डेस्कटोप', 0.5)
# ('Position', 'स्थिति', 0.5714285714285714)
# ('Offset', 'ओफसेट', 0.5714285714285714)
# ('Name', 'नाम', 0.75)
# ('URI', 'यूआरआई', 0.6)
# ('Plugin', 'प्लग-इन', 0.6666666666666666)
# ('Native', 'वतनी', 0.5)
# ('LDTP', 'एलडीटीपी', 0.6153846153846154)

# %%
import json

with open("data/processed/aligned_pairs_10k.json", "w", encoding = "utf-8") as f:
    json.dump(aligned_pairs, f, ensure_ascii = False, indent = 2)

# %%
import json

with open("data/processed/aligned_pairs_10k.json", encoding = "utf-8") as f:
    aligned_pairs = json.load(f)

# %%
deduped = {}

for en, hi, score in aligned_pairs:
    key = (en.lower(), hi)

    if key not in deduped or score > deduped[key][2]:
        deduped[key] = (en, hi, score)

# %%
deduped_pairs = list(deduped.values())

# %%
COMMON_ENGLISH = {
    "the", "give", "allow", "show", "hide", "name", "position",
    "default", "settings", "file", "view", "edit", "help",
    "use", "using", "used", "set", "get", "add", "remove"
}

# %%
filtered_pairs = []

for en, hi, score in deduped_pairs:
    if en.lower() in COMMON_ENGLISH:
        continue
    filtered_pairs.append((en, hi, score))

print("Before: ", len(aligned_pairs))
print("After dedup: ", len(deduped_pairs))
print("After filtering: ", len(filtered_pairs))

for pair in filtered_pairs[:20]:
    print(pair)
# Out:
# Before:  0
# After dedup:  667
# After filtering:  645
# ('Highlight', 'हाइलाइट', 0.5882352941176471)
# ('API', 'एपीआई', 0.5)
# ('IPython', 'आईपाइथन', 0.5882352941176471)
# ('Console', 'कन्सोल', 0.5714285714285714)
# ('Monitor', 'मानिटर', 0.6666666666666666)
# ('WIDGET', 'विडजेट', 0.5714285714285714)
# ('Alpha', 'अल्फा', 1.0)
# ('Des', 'डेस्कटोप', 0.5)
# ('Offset', 'ओफसेट', 0.5714285714285714)
# ('URI', 'यूआरआई', 0.6)
# ('Plugin', 'प्लग-इन', 0.6666666666666666)
# ('Native', 'वतनी', 0.5)
# ('LDTP', 'एलडीटीपी', 0.6153846153846154)
# ('Recorder', 'रेकोर्डर', 0.7058823529411765)
# ('Creates', 'करता', 0.46153846153846156)
# ('num1', '(num1)', 0.8)
# ('Accerciser', 'इसे', 0.46153846153846156)
# ('Changes', 'आएंगे।', 0.46153846153846156)
# ('Node', '(नोड)', 0.6)
# ('Alt', 'आल्ट', 0.8571428571428571)

# %%
with open("data/processed/aligned_pairs_10k_clean.json", "w", encoding = "utf-8") as f:
    json.dump(filtered_pairs, f, ensure_ascii = False, indent = 2)

# %%
MAX_LINES = 50000
SIM_THRESHOLD = 0.5

COMMON_ENGLISH = {
    "the", "give", "allow", "show", "hide", "name", "position",
    "default", "settings", "file", "view", "edit", "help",
    "use", "using", "used", "set", "get", "add", "remove"
}

nlp = spacy.load("en_core_web_sm", disable = ["parser", "lemmatizer"])

def is_title_like(doc):
    """
    Heuristic: sentence is title-like if it has no verb
    """
    return not any(token.pos_ == "VERB" for token in doc)

def romanize_hi(word):
    try:
        return transliterate(word, sanscript.DEVANAGARI, sanscript.ITRANS)
    except Exception:
        return ""

def similarity(a,b):
    return SequenceMatcher(None, a.lower(), b.lower()).ratio()

en_file = Path("data/raw/parallel-n/IITB.en-hi.en")
hi_file = Path("data/raw/parallel-n/IITB.en-hi.hi")

en_lines, hi_lines = [], []

with open(en_file, encoding = "utf-8") as f_en, open(hi_file, encoding = "utf-8") as f_hi:
    for i, (en, hi) in enumerate(zip(f_en, f_hi)):
        if i >= MAX_LINES:
            break
        en_lines.append(en.strip())
        hi_lines.append(hi.strip())

print(f"Loaded {len(en_lines)} sentence pairs")

aligned_pairs = set()

for en_sent, hi_sent in zip(en_lines, hi_lines):
    doc = nlp(en_sent)
    title_like = is_title_like(doc)

    en_names = set()

    for ent in doc.ents:
        if ent.label_ in {"PERSON", "ORG", "PRODUCT", "GPE"}:
            en_names.add(ent.text)
    
    for token in doc:
        if(token.text[0].isupper() and token.is_alpha and len(token.text) > 2 and token.text.lower() not in COMMON_ENGLISH and (token.i != 0 or title_like)):
            en_names.add(token.text)

    if not en_names:
        continue
        
    if len(aligned_pairs) == 0:
        print("EN SENT: ", en_sent)
        print("EN NAMES: ", en_names)
        print("HI SENT: ", hi_sent)
        print("-" * 50)

    hi_tokens = hi_sent.split()

    for en_name in en_names:
        if en_name.lower() in COMMON_ENGLISH:
            continue

        best_match = None
        best_score = 0.0

        for hi_word in hi_tokens:
            hi_roman = romanize_hi(hi_word)

            if abs(len(en_name) - len(hi_roman)) > 6:
                continue
                
            score = similarity(en_name, hi_roman)

            if score > best_score:
                best_score = score
                best_match = hi_word

        if best_score >= SIM_THRESHOLD:
            aligned_pairs.add((
                en_name,
                best_match,
                round(best_score, 3)
            ))

aligned_pairs = list(aligned_pairs)

print("Total aligned pairs: ", len(aligned_pairs))

with open("data/processed/aligned_pairs_50k.json", "w", encoding = "utf-8") as f:
    json.dump(aligned_pairs, f, ensure_ascii = False, indent = 2)

print("Saved aligned_pairs_50k.json")
# Out:
# Loaded 50000 sentence pairs
# EN SENT:  Accerciser Accessibility Explorer
# EN NAMES:  {'Accessibility', 'Accerciser', 'Explorer'}
# HI SENT:  एक्सेर्साइसर पहुंचनीयता अन्वेषक
# --------------------------------------------------
# EN SENT:  Highlight duration
# EN NAMES:  {'Highlight'}
# HI SENT:  अवधि को हाइलाइट रकें
# --------------------------------------------------
# Total aligned pairs:  1482
# Saved aligned_pairs_50k.json

# %%
aligned_pairs
# Out:
# [('Quit Anjuta', 'Anjuta', 0.706),
#  ('PURPOSE', 'PURPOSE.', 0.933),
#  ('Reset', 'रिसेट', 0.727),
#  ('Fontconfig', 'फ़ॉन्टकॉन्फ़िग', 0.583),
#  ('Demo', 'डेमो', 1.0),
#  ('JHBuild', 'बिल्ड', 0.667),
#  ('Mail', 'नई', 0.571),
#  ('Tasks', 'अक्षर', 0.5),
#  ('XDG', '"XDG', 0.857),
#  ('Drag Axis', 'ड्रैग', 0.667),
#  ('Pager', 'पेजर', 0.545),
#  ('Profile', 'प्रोफाइल', 0.625),
#  ('See', 'See', 1.0),
#  ('Simulation', '(सिमुलेशन)', 0.609),
#  ('Mail', 'रही', 0.5),
#  ('Menus', 'मेनू', 0.889),
#  ('GPU', 'GPU', 1.0),
#  ('USA', 'इस', 0.667),
#  ('DOS EOL', 'EOL', 0.6),
#  ('All', 'काल', 0.571),
#  ('Zebra', 'जेब्रा', 0.8),
#  ('Baltic', 'बाल्टिक', 0.769),
#  ('Arguments', 'आर्गुमेंट्स', 0.842),
#  ('About', 'अंजूटा', 0.545),
#  ('Log', 'Log', 1.0),
#  ('URI', 'URI', 1.0),
#  ('Finnish', 'फिनिश', 0.667),
#  ('LDAP', 'LDAP', 1.0),
#  ('Transcode', 'ट्रांसकोड', 0.632),
#  ('Domain Name', 'डोमेन', 0.588),
#  ('Refresh', 'रिफ्रेश', 0.625),
#  ('Hebrew', 'हिब्रू', 0.545),
#  ('Checksum', 'चेकसम', 0.706),
#  ('ccc - analyzer', 'ccc-analyzer:', 0.889),
#  ('Django', 'जैंगो', 0.667),
#  ('European', 'यूरोपीय', 0.625),
#  ('Pixbuf', 'Pixbuf', 1.0),
#  ('Plugin', 'प्लगिन', 0.769),
#  ('Photo', 'फोटो', 1.0),
#  ('Bug', 'bug', 1.0),
#  ('Template', 'टेम्पलेट', 0.706),
#  ('Save', 'इस', 0.571),
#  ('MERCHANTABILITY', 'मर्केंटेबिलिटी', 0.552),
#  ('Support', 'सपोर्ट', 0.714),
#  ('Terminal', 'टर्मिनल', 0.824),
#  ('Please', 'पहले', 0.5),
#  ('GnomeCard', 'जीनोम', 0.533),
#  ('Odessa', 'ओडेसा', 0.909),
#  ('Free', 'करेगे;', 0.545),
#  ('Menu Mode', 'मेन्यू', 0.571),
#  ('Monte Carlo', 'मोन्ते', 0.625),
#  ('Wrapper', 'रैपर', 0.571),
#  ('Load', 'लोड', 0.75),
#  ('Commit', 'कमिट', 0.5),
#  ('Reload', 'लोड', 0.6),
#  ('Tag De', 'टैग', 0.545),
#  ('Pixmap', 'पिक्समैप', 0.625),
#  ('OPAL', 'OPAL,', 0.889),
#  ('Identity', 'आयडेंटिटी', 0.556),
#  ('Thread', 'पीथ्रेड्स', 0.667),
#  ('API Help', 'API', 0.545),
#  ('DPI', 'डीपीआई', 0.667),
#  ('GStreamer', 'gstreamer', 1.0),
#  ('Load Log', 'लाग', 0.5),
#  ('Vitamin D - -', 'विटामिन', 0.667),
#  ('MiB', 'MiB):', 0.75),
#  ('Programs', 'प्रोग्राम', 0.875),
#  ('Tone', '("Tone"', 0.727),
#  ('Softphone', 'सॉफ्टफोन', 0.571),
#  ('Target', 'करें', 0.545),
#  ('GNOME', 'मे', 0.571),
#  ('Show Cogl', 'Cogl', 0.615),
#  ('Scratchbox', 'Scratchbox', 1.0),
#  ('Passphrase', 'पास', 0.571),
#  ('H323', 'H323', 1.0),
#  ('IMAP', 'मैप', 0.667),
#  ('Filters', 'फिल्टरों', 0.5),
#  ('API', 'टैग', 0.5),
#  ('DTS', 'डीटीएस', 0.6),
#  ('GtkSourceView', 'GtkSourceView', 1.0),
#  ('General', 'गुण', 0.545),
#  ('Flag', 'फ्लैग', 0.545),
#  ('Select Program', 'प्रोग्राम', 0.636),
#  ('Scoring', 'स्कोरिंग', 0.667),
#  ('Text', 'CD-Text', 0.727),
#  ('Tint', 'टिंट', 0.667),
#  ('Second', 'सेकेण्ड', 0.615),
#  ('All', 'खाली', 0.5),
#  ('Package', 'पैकेजः', 0.533),
#  ('You', 'युक्त', 0.5),
#  ('Log', 'लॉग', 0.5),
#  ('Flash', 'फ़्लैश', 0.833),
#  ('Enable', 'php/Enable', 0.75),
#  ('Deal', 'डील', 0.5),
#  ('Select Folder', 'फ़ोल्डर', 0.5),
#  ('Whitehead', '(व्हाइटहेड)', 0.571),
#  ('PHP', 'पीएचपी', 0.545),
#  ('Memcheck', 'मेमोरीजांच', 0.5),
#  ('XSPF', 'XSPF', 1.0),
#  ('Franklin', 'Franklin', 1.0),
#  ('MyAccount', 'MyAccount', 1.0),
#  ('Tableau', 'ताश', 0.5),
#  ('Profile', 'फाइलें', 0.571),
#  ('Agnes', 'एग्नेस', 0.727),
#  ('Save Message', 'संदेश', 0.6),
#  ('MiB', 'MiB', 1.0),
#  ('Subversion', 'VERSION)', 0.778),
#  ('Demo', 'डेमो!', 0.889),
#  ('Memory', 'में', 0.667),
#  ('GNOME', 'ग्नोम', 0.8),
#  ('Homepage', 'होमपेज', 0.625),
#  ('Subversion', 'सबवर्सन', 0.571),
#  ('Delete', '"Delete"', 0.857),
#  ('Data', 'हटाएं', 0.6),
#  ('All', 'फ़ाइल', 0.5),
#  ('SECAM', 'सीकैम', 0.5),
#  ('Linux', 'लेकिन', 0.545),
#  ('Catalan', 'केटेलन', 0.533),
#  ('Fifth Floor', 'Fifth', 0.625),
#  ('Track', 'ट्रैक', 0.727),
#  ('Boston', 'बोस्टन,', 0.714),
#  ('Copy', 'Copy]', 0.889),
#  ('Hang', 'हैंग', 0.6),
#  ('packets:%', 'packets:%.', 0.947),
#  ('DisplayName', 'डिसप्लेनाम', 0.727),
#  ('Photo Mode', 'फोटो', 0.667),
#  ('Plugins', 'प्लगइंस', 0.625),
#  ('Blanc', 'Noir/Blanc', 0.667),
#  ('Westhaven', 'वेस्ट', 0.571),
#  ('Resizable', 'Resizable', 1.0),
#  ('Macros', 'मेक्रो', 0.545),
#  ('Files', 'फाइलें', 0.5),
#  ('Are', 'date', 0.571),
#  ('Anjuta', 'अंजुता', 0.833),
#  ('GdkColor', 'Gdkcolor', 1.0),
#  ('Computer', 'कम्प्यूटर', 0.556),
#  ('URI', 'यूआरआई', 0.6),
#  ('Monitor', 'मॉनीटर', 0.625),
#  ('French', 'फ्रेंच', 0.571),
#  ('Defaults', 'डिफाल्ट', 0.5),
#  ('ParamSpec', 'ParamSpec', 1.0),
#  ('Cogl', 'cogl', 1.0),
#  ('s% s', 's%', 0.667),
#  ('Database', 'डेटाबेस', 0.625),
#  ('Struct', 'सट्रक्ट', 0.571),
#  ('Draftbox', 'ड्राफ्टबाक्स', 0.5),
#  ('SamplePlugin', 'प्लगइन', 0.5),
#  ('Mac', 'Mac', 1.0),
#  ('Profiling', 'प्रोफाइलिंग', 0.667),
#  ('HTTPS', '(HTTPS)', 0.833),
#  ('Parameters', 'पंक्ति', 0.5),
#  ('CoglObject', 'CoglObject', 1.0),
#  ('Booth', 'बूथ', 0.6),
#  ('PHOTO', 'फोटो', 1.0),
#  ('Java Module', 'मोड्यूल', 0.556),
#  ('Data', 'नाम', 0.5),
#  ('Invalid >', 'अवैध', 0.5),
#  ('Services', 'सेवाएं', 0.571),
#  ('Share', 'साझा', 0.6),
#  ('GType', 'GType', 1.0),
#  ('Project Name', 'परियोजना', 0.545),
#  ('the%', 'थे', 0.857),
#  ('Animations', 'एनीमेशन', 0.5),
#  ('MIME', 'MIME', 1.0),
#  ('Cell', 'सेल', 0.5),
#  ('Module', 'मोड्यूल', 0.769),
#  ('GL', 'GL', 1.0),
#  ('Address', 'करें', 0.5),
#  ('Repository', 'रेपोसिटरी', 0.8),
#  ('PAL', 'PAL/SECAM', 0.5),
#  ('Redeal', 'रिडील', 0.5),
#  ('Hypertext', 'हायपर-टेक्स्ट', 0.583),
#  ('Chinese', 'चीनी', 0.667),
#  ('Toggle Bookmark', 'बुकमार्क', 0.5),
#  ('Password', 'पासवर्ड', 0.588),
#  ('Local', 'लोकल', 0.727),
#  ('Contacts', 'Contacts,', 0.941),
#  ('Saratoga', 'साराटोगा', 1.0),
#  ('DVD - RAM', 'डीवीडी-रैम', 0.667),
#  ('Osmosis', 'ऑस्मोसिस', 0.8),
#  ('GObject', '+/GObject', 0.875),
#  ('Antialias', 'एंटीएलियास', 0.6),
#  ('GTKmm', 'GTKmm', 1.0),
#  ('Simulation', 'सिमुलेशन', 0.667),
#  ('Simplified', 'सिम्लिफाइड', 0.667),
#  ('Ukrainian', 'युकेरियन', 0.632),
#  ('MA 02110 - 1301', '02110-1301,', 0.769),
#  ('Buffer', 'बफ़र', 0.5),
#  ('recent menu', 'recent', 0.706),
#  ('About', 'Anjuta', 0.545),
#  ('Slices', 'स्लाइस', 0.667),
#  ('Downloads', 'डाउनलोड', 0.556),
#  ('Vietnamese', 'विएतनामी', 0.737),
#  ('Maildir', 'dir', 0.6),
#  ('Class', 'Class', 1.0),
#  ('Uncoated', 'coating', 0.533),
#  ('popup menu', 'मेन्यू', 0.533),
#  ('Folders', 'फ़ोल्डर', 0.714),
#  ('Plait', 'लपेट', 0.545),
#  ('Changelog', 'changeLog', 1.0),
#  ('PATH', 'पथ', 0.889),
#  ('Save', 'सहेजें', 0.545),
#  ('Latvian', 'लटावियन', 0.824),
#  ('Window', 'विंडो', 0.545),
#  ('Video', 'video"', 0.909),
#  ('H. 245', '245', 0.667),
#  ('This', 'थे', 0.571),
#  ('Wallpaper', 'वॉलपेपर', 0.6),
#  ('Cable', 'DSL/Cable', 0.714),
#  ('Icons', 'Icons', 1.0),
#  ('Always', 'कॉल', 0.545),
#  ('Treemap', 'ट्रीमैप', 0.667),
#  ('Channel', 'चैनलः', 0.625),
#  ('Issuer', 'Issuer', 1.0),
#  ('MMM', 'MMM', 1.0),
#  ('Trigger', 'ट्रिगर', 0.714),
#  ('VIDEO', 'वीडियो', 0.727),
#  ('Regular', 'रेग्युलर', 0.875),
#  ('Lisp', 'लिप्स', 0.667),
#  ('Video', 'डीवीडी', 0.545),
#  ('TOS', '(TOS):', 0.667),
#  ('Folder', 'Folder"', 0.923),
#  ('Gnome', 'Gnome', 1.0),
#  ('Fortran', 'फोर्ट्रान', 0.75),
#  ('Realm', 'फ्रेम', 0.545),
#  ('AisleRiot', 'एसलिरियोट', 0.6),
#  ('Import', 'Import', 1.0),
#  ('Pango', 'पैंगो', 0.727),
#  ('Vala', 'वाला', 1.0),
#  ('Double', 'दोगुना', 0.5),
#  ('Out', 'आउट', 0.571),
#  ('Move', 'में', 0.571),
#  ('Expression', 'एक्सप्रेशन.', 0.522),
#  ('Pid', 'पीआईडी', 0.667),
#  ('GdkDisplay', 'GdkDisplay', 1.0),
#  ('Gaps', 'गैप्स', 0.8),
#  ('License', 'License', 1.0),
#  ('LAN', 'LAN', 1.0),
#  ('GNOME', 'GNOME', 1.0),
#  ('Moving', '"Moving', 0.923),
#  ('Memcheck', 'Memcheck', 1.0),
#  ('Filter', 'फ़िल्टर', 0.769),
#  ('Implementation', 'इम्प्लीमेंटेशन', 0.621),
#  ('IRIVER', 'IRIVER', 1.0),
#  ('DSL', 'DSL/Cable', 0.5),
#  ('Menu', 'मेनू', 1.0),
#  ('Projects', 'प्रोजेक्ट', 0.75),
#  ('URL', '(URL):', 0.667),
#  ('AisleRiot', 'एस्लेरियॉट', 0.6),
#  ('Albert', 'अलबर्ट', 0.714),
#  ('Italian', 'इटालियन', 0.875),
#  ('Regular', '(रेगुलर)', 0.824),
#  ('Commit', 'मिटाएं', 0.5),
#  ('Napoleons', 'नेपोलियन', 0.526),
#  ('Save', 'संदेश', 0.5),
#  ('DevHelp', 'DevHelp', 1.0),
#  ('PID', 'PID', 1.0),
#  ('Make', 'में', 0.571),
#  ('DVD', '"CD/DVD', 0.6),
#  ('1f%% Jitter', 'Jitter', 0.706),
#  ('Directory', 'डिरेक्ट्री...', 0.6),
#  ('Project Type', 'प्रोजेक्ट', 0.6),
#  ('Brasero', 'ब्रेसेरो', 0.857),
#  ('GStreamer', 'GStreamer', 1.0),
#  ('Profile Name', 'प्रोजेक्ट', 0.5),
#  ('FAQ', 'FAQ', 1.0),
#  ('Monitor', 'मानिटर', 0.667),
#  ('Growisofs', 'Growisofs', 1.0),
#  ('Korean', 'कोरियन', 0.714),
#  ('Minutes', 'मिनट', 0.615),
#  ('GObject', 'GObject', 1.0),
#  ('ClutterPath', 'ClutterPath', 1.0),
#  ('Drive', 'ड्राइव', 0.727),
#  ('Shared', 'साझा', 0.545),
#  ('Hotkey', 'hotkey', 1.0),
#  ('System', 'सिस्टमः', 0.571),
#  ('Data', 'सेट', 0.5),
#  ('Path', 'पाथः', 0.8),
#  ('dialog1', 'डायलाग', 0.533),
#  ('Code', 'मोड़ें', 0.6),
#  ('PIN', 'पिन', 0.857),
#  ('ASCII', 'है', 0.5),
#  ('Core', 'रहे', 0.5),
#  ('LAN', 'LAN,', 0.857),
#  ('Data', '(डेटा', 0.667),
#  ('Phrase', 'फ्रेज', 0.667),
#  ('Eyetracker', 'आईट्रैकर', 0.5),
#  ('Gravity', 'ग्रैविटी', 0.8),
#  ('Burning', 'बर्निंग', 0.667),
#  ('Autoformat', 'Autoformat', 1.0),
#  ('Trash', 'ट्रेश', 0.727),
#  ('Autotools', 'आटोटूल', 0.625),
#  ('Local MH', 'लोकल', 0.571),
#  ('Aisleriot', 'एसलिरियोट', 0.6),
#  ('Directories', 'डायरेक्ट्री', 0.571),
#  ('Reload', 'री-लोड', 0.615),
#  ('Split', 'लिए', 0.5),
#  ('Java', 'जावा', 1.0),
#  ('USB', 'USB', 1.0),
#  ('Tab', 'टैब', 0.75),
#  ('Tabs', 'टैब्स', 0.8),
#  ('Libraries', 'लायब्रेरी', 0.556),
#  ('Royal', 'रॉयल', 0.667),
#  ('e. g. / dev / video0', '(उदा./dev/video0)', 0.649),
#  ('Standby', 'स्टैंडबाए', 0.588),
#  ('Nickname', 'नाम', 0.5),
#  ('GTKmm (Simple', '(Simple)', 0.667),
#  ('Bug Buddy', 'Buddy', 0.714),
#  ('Struct', 'Struct', 1.0),
#  ('RFC2833', 'RFC2833', 1.0),
#  ('Toolbars', 'टूलबाक्सों', 0.556),
#  ('Atlas', 'ऐटलस', 0.769),
#  ('Mail', 'आई', 0.667),
#  ('Gatekeeper', 'गेटकीपर', 0.5),
#  ('Choose', 'चुनें', 0.5),
#  ('Folders', 'फ़ाइल/फ़ोल्डर', 0.5),
#  ('Nautilus', 'नॉटिलस', 0.706),
#  ('Traditional', 'ट्रेडिशनल', 0.609),
#  ('Flex', 'लिए', 0.571),
#  ('Sysm', 'सिस्टम', 0.545),
#  ('Debug', 'डीबग', 0.545),
#  ('max', 'कम', 0.571),
#  ('Registry', 'रजिस्ट्री', 0.625),
#  ('Buddy', 'बड्डी', 0.6),
#  ('Call', 'काल', 0.5),
#  ('Report', 'रपट', 0.5),
#  ('UI', 'UI', 1.0),
#  ('IPython', 'आईपाइथन', 0.588),
#  ('Stylus', 'स्टाइलस', 0.571),
#  ('Polish', 'पालिश', 0.769),
#  ('Yacc', 'Yacc', 1.0),
#  ('Buddy', 'Buddy', 1.0),
#  ('PID', 'पीआईडी', 0.667),
#  ('Series', 'Series', 1.0),
#  ('This', 'है.', 0.5),
#  ('Extern', 'Extern', 1.0),
#  ('Usage', 'उपयोग', 0.5),
#  ('WARRANTY', 'warranty', 1.0),
#  ('Folder', 'फ़ोल्डरः', 0.714),
#  ('Right', 'शिफ्ट', 0.5),
#  ('Mode', 'मोड', 0.75),
#  ('Display', 'डिवाइस', 0.571),
#  ('GNU', 'GNU', 1.0),
#  ('This', 'है', 0.571),
#  ('Brasero - Burning', 'ब्रैसेरो-सीडी', 0.6),
#  ('SASL', 'SASL', 1.0),
#  ('Marshaller', 'मार्शलर', 0.8),
#  ('Load Log', 'लोड', 0.5),
#  ('Library', 'लाइब्रेरी', 0.667),
#  ('URL', 'URL', 1.0),
#  ('Dialpad', 'Dialpad,', 0.933),
#  ('Children', 'चिल्ड्रन', 0.824),
#  ('Vitamin', 'विटामिन', 0.933),
#  ('Hex', 'हेक्स', 0.5),
#  ('Remote', 'करें…', 0.5),
#  ('Copyright', 'Copyright', 1.0),
#  ('Directory:%', 'डायरेक्टरी:%', 0.583),
#  ('PLS', 'पीएलएस', 0.545),
#  ('Pixel', 'पिक्सेल', 0.667),
#  ('INFO', '("INFO"', 0.727),
#  ('Treat', 'तरह', 0.545),
#  ('Break', 'ब्रेक', 0.8),
#  ('Registrar', 'रजिस्ट्रार', 0.737),
#  ('Resolution:%', 'Resolution:%', 1.0),
#  ('General', 'ग्नू-जनरल', 0.526),
#  ('Ekiga', 'एकिगा', 1.0),
#  ('Development', 'Development', 1.0),
#  ('Enum', 'Enum', 1.0),
#  ('River', 'रिवर', 0.727),
#  ('Body', 'बाडी', 0.5),
#  ('Valid', 'वैधः', 0.667),
#  ('Photos', 'फोटो', 0.909),
#  ('WITHOUT', 'WITHOUT', 1.0),
#  ('Linker', 'लिंकर', 0.615),
#  ('Site', 'साइटः', 0.6),
#  ('Video', '(वीडियो', 0.667),
#  ('Domain', 'डोमेन', 0.667),
#  ('Screencast', 'स्क्रीनकास्ट', 0.571),
#  ('Kernel', 'कर्नल', 0.615),
#  ('Files', '(File', 0.8),
#  ('Spanish', 'स्पेनिश', 0.8),
#  ('Netmeeting', 'नेटमीटिंग', 0.667),
#  ('Repository', 'रेपोसिटरीः', 0.762),
#  ('XOFF', 'XOFF', 1.0),
#  ('Lua', 'Lua', 1.0),
#  ('Select', 'से', 0.5),
#  ('METHOD', 'METHOD', 1.0),
#  ('Dutch', 'डच', 0.6),
#  ('IP Telephony', 'टेलिफोनी,', 0.636),
#  ('Done', 'Done)', 0.889),
#  ('Anjuta Kick', 'Anjuta', 0.706),
#  ('Fatal', 'फेटल', 0.5),
#  ('Click', 'लिंक', 0.6),
#  ('Please', 'Please', 1.0),
#  ('Widgets', 'विजेट्स', 0.571),
#  ('Mac', 'अंत', 0.571),
#  ('Hypertext', 'हायपरटेक्स्ट', 0.609),
#  ('Japanese', 'जापानीज', 0.625),
#  ('Breakpoint', 'ब्रेकपाइंट', 0.667),
#  ('Windows', 'विंडो', 0.5),
#  ('Mailbox', 'फाइलों', 0.571),
#  ('XML', 'xml-rpc', 0.6),
#  ('Image', 'इमेज़', 0.6),
#  ('Project Name', 'प्रोजेक्ट', 0.7),
#  ('License', 'इसे', 0.6),
#  ('Username', 'नाम', 0.5),
#  ('Note', 'नोट', 0.75),
#  ('Street', 'स्ट्रीट,', 0.615),
#  ('GPL', 'GPL', 1.0),
#  ('GStreamer', '(GStreamer', 0.947),
#  ('Xlib', 'Xlib', 1.0),
#  ('Font', 'फ़ॉन्ट.', 0.545),
#  ('Debug', 'डिबग', 0.545),
#  ('YUV', 'YUV', 1.0),
#  ('Caribou', 'कैरिबो', 0.714),
#  ('Number', 'नंबर', 0.615),
#  ('First', 'इसे', 0.5),
#  ('Binding', 'बाइंडिंग', 0.625),
#  ('Valgrind', 'वालग्रिंड', 0.778),
#  ('Account', 'आउट', 0.545),
#  ('Tags', 'Tags', 1.0),
#  ('Editor', 'एडीटर', 0.769),
#  ('Plugin Name', 'प्लगइन', 0.632),
#  ('Sieve', 'सीव', 0.667),
#  ('DTMF Mode', 'DTMF', 0.615),
#  ('Scan', 'स्कैन', 0.6),
#  ('Pass', 'पास', 0.75),
#  ('DVDCSS', '"DVDCSS', 0.923),
#  ('Fifth', 'Fifth', 1.0),
#  ('Many', 'कंपनी', 0.545),
#  ('Action', 'OPTION', 0.667),
#  ('Today', 'days', 0.667),
#  ('Filename', 'फ़ाइलनाम', 0.706),
#  ('Service', 'सेवा', 0.545),
#  ('Identity', 'आयडेंटीटी', 0.556),
#  ('Noir', 'Noir/Blanc', 0.571),
#  ('Global', 'ग्रैब', 0.5),
#  ('gcj', 'gcj', 1.0),
#  ('Codecs:%', 'Codecs:%', 1.0),
#  ('New', 'लेने', 0.571),
#  ('Font Hinting', 'हिंटिंग', 0.5),
#  ('EOL', 'EOL', 1.0),
#  ('Reply', 'प्ले', 0.5),
#  ('TX', 'TX', 1.0),
#  ('Bind', 'ID', 0.667),
#  ('Modem', 'मॉडेम', 0.667),
#  ('Bad', 'बुरा', 0.571),
#  ('Theme', 'थीम', 0.6),
#  ('GiB', 'GiB', 1.0),
#  ('QoS', '(QoS)', 0.75),
#  ('Highlight', 'हाइलाइट', 0.588),
#  ('Fingerprint', 'फ़िंगरप्रिंटः', 0.64),
#  ('Treemap Chart', 'ट्रीमैप', 0.571),
#  ('Accordion', 'एकार्डियन', 0.526),
#  ('num1', '(num1)', 0.8),
#  ('German', 'जर्मन', 0.615),
#  ('Pattern', 'पैटर्नः', 0.625),
#  ('CPU', 'CPU', 1.0),
#  ('Franklin', 'फ्रेंकलिन', 0.526),
#  ('Setter', 'सेटर', 0.667),
#  ('Basic', 'बेसिक', 0.545),
#  ('Clean Project', 'प्रोजेक्ट', 0.571),
#  ('Software', 'सॉफ़्टवेयर', 0.5),
#  ('Quota', 'कोटेड', 0.545),
#  ('Balsa', 'बल्सा:%', 0.833),
#  ('With', 'the', 0.571),
#  ('Stash', 'संदेश', 0.615),
#  ('Mac', 'MacOS', 0.75),
#  ('max', 'max):', 0.75),
#  ('Mouse', 'माउस', 0.6),
#  ('Loading', 'लोड', 0.545),
#  ('ClutterBackend', 'ClutterBackend', 1.0),
#  ('s,%', 's,%', 1.0),
#  ('Clean Module', 'मोड्यूल', 0.526),
#  ('Lesser', 'Lesser', 1.0),
#  ('Mary', 'आंट', 0.5),
#  ('Tone', '"Tone"', 0.8),
#  ('Quit Balsa', 'बल्सा:%', 0.588),
#  ('USA', 'USA.', 0.857),
#  ('Orientation', 'इंडेन्टेशन', 0.522),
#  ('Mark', 'पर', 0.5),
#  ('Send', 'से', 0.667),
#  ('Gordons', 'गोरडोन्स', 0.875),
#  ('New Directory', 'डिरेक्ट्री...', 0.5),
#  ('Stream', 'स्ट्रीम', 0.667),
#  ('TCP', 'TCP', 1.0),
#  ('Menu', 'मेन्यू', 0.889),
#  ('Link', "Link'", 0.889),
#  ('Insert', 'से', 0.5),
#  ('Recording', 'रिकार्डिंग', 0.526),
#  ('Account', 'MyAccount', 0.875),
#  ('-%', '%', 0.667),
#  ('Program', 'अनुप्रयोग', 0.588),
#  ('Javascript', 'JavaScript', 1.0),
#  ('Reset', 'रीसेट', 0.727),
#  ('Stash', 'स्थिति', 0.545),
#  ('BSD', '(बीएसडी)', 0.5),
#  ('DVDs', 'DVD', 0.857),
#  ('Timestamp', 'टाइमस्टैंप', 0.762),
#  ('SVCDs', 'SVCD', 0.889),
#  ('Linux', '(Linux', 0.909),
#  ('Tile', 'टाइल', 0.667),
#  ('BDs', 'बीडी', 0.571),
#  ('High', 'hi.', 0.571),
#  ('Integrated', 'Integrated', 1.0),
#  ('This', 'था', 0.571),
#  ('Patch', 'Patch', 1.0),
#  ('Macro', 'मेक्रो', 0.6),
#  ('Parameters', 'पैरामीटर्सः', 0.696),
#  ('d%%', 'd%%', 1.0),
#  ('Trust', 'ट्रस्ट', 0.727),
#  ('Burner', 'बर्नर', 0.615),
#  ('MA 02110 - 1301', '02110-1301', 0.8),
#  ('Shortcuts', 'शॉर्टकट्स', 0.571),
#  ('Pileon', 'पाइलेअन', 0.714),
#  ('Ctrl', 'Ctrl-C', 0.8),
#  ('Type', 'तेज', 0.5),
#  ('Object', 'आब्जेक्ट', 0.615),
#  ('TLS', 'TLS', 1.0),
#  ('Developer', 'डेवलपर', 0.632),
#  ('Parallel', 'और', 0.5),
#  ('Slicing', 'स्लाइसिंग', 0.625),
#  ('Royal East', 'रॉयल', 0.588),
#  ('Profiles', 'फाइल्स', 0.533),
#  ('Email', 'में', 0.5),
#  ('Space', 'सफेद', 0.5),
#  ('Syne', 'स्याने', 0.889),
#  ('Make', 'मेक', 0.5),
#  ('Vob', 'Vob', 1.0),
#  ('DIRECTORY', '[DIRECTORY]', 0.9),
#  ('Preview', 'पूर्व', 0.5),
#  ('Chooser', '"Chooser"', 0.875),
#  ('New', 'New', 1.0),
#  ('String', '"String"', 0.857),
#  ('Panel', 'पैनल', 0.667),
#  ('Flat', 'फ्लैट', 0.545),
#  ('Fast Start', 'स्टार्ट', 0.625),
#  ('Border', 'बॉर्डर', 0.571),
#  ('Kick', 'किक', 0.75),
#  ('Camelot', 'केमेलॉट', 0.5),
#  ('Base', 'बेस', 0.5),
#  ('Warning', 'वार्निंग', 0.667),
#  ('RPC', 'xml-rpc', 0.6),
#  ('Anjuta', 'मैन', 0.545),
#  ('Please', 'लेकिन', 0.5),
#  ('Tiles', 'टाइल', 0.6),
#  ('Threaded', 'थ्रेडिंग', 0.588),
#  ('Bakers', 'बेकर्स', 0.615),
#  ('Foundation', 'Foundation,', 0.952),
#  ('Click', 'क्लिक', 0.6),
#  ('URL', 'यूआरएलः', 0.5),
#  ('Minimal', '(Minimal)', 0.875),
#  ('Setup', 'सेटअप', 0.667),
#  ('Style', 'स्टाइल', 0.545),
#  ('DVD', 'डीवीडी', 0.667),
#  ('tuv', 'tuv', 1.0),
#  ('MIME', 'में', 0.571),
#  ('Home', 'होम', 0.75),
#  ('Diff', 'Diff…', 0.889),
#  ('VoIP', 'VoIP,', 0.889),
#  ('node', 'नोड', 0.75),
#  ('Readcd / Readom', 'Readcd/Readom', 0.929),
#  ('General', 'General', 1.0),
#  ('Plugin', 'प्लगइन', 0.714),
#  ('Schema', 'स्कीमाः', 0.5),
#  ('Valgrind', 'Valgrind', 1.0),
#  ('Glenwood', 'ग्लेनवुड', 0.588),
#  ('Graph', 'ग्राफ', 0.909),
#  ('Panel', 'पटल', 0.545),
#  ('Connected', 'कनेक्टेड%', 0.526),
#  ('Past', 'date', 0.5),
#  ('dialog3', 'डायलाग', 0.533),
#  ('Remote', 'Remote,', 0.923),
#  ('UserName', 'नाम', 0.5),
#  ('mm tt', 'mm', 0.571),
#  ('Plugins', 'प्लगइन्स', 0.75),
#  ('Node', '(नोड)', 0.6),
#  ('Photo Path', 'फोटो', 0.667),
#  ('RFC', 'RFC', 1.0),
#  ('i.', 'i', 0.667),
#  ('Registrar', 'रजिस्ट्रारः', 0.7),
#  ('Crash', 'क्रैश', 0.667),
#  ('MERCHANTABILITY', 'MERCHANTABILITY', 1.0),
#  ('H. 239', '239', 0.667),
#  ('Stash', 'सत्र', 0.6),
#  ('Floor', 'Floor,', 0.909),
#  ('GtkSourceview', 'GtkSourceview', 1.0),
#  ('Telephony', 'टेलिफोनी,', 0.737),
#  ('MDN', 'निम्न', 0.5),
#  ('Package', 'पैकेज', 0.571),
#  ('NPOT', 'NPOT', 1.0),
#  ('Serial', 'सीरियल', 0.714),
#  ('Output', 'आउटपुट', 0.714),
#  ('CVS', 'CVS:', 0.857),
#  ('Profile', 'प्रोफ़ाइल', 0.8),
#  ('Gay Gordons', 'गोरडोन्स', 0.7),
#  ('Protocols', 'प्रोटोकॉल', 0.632),
#  ('Tool', 'टूल', 0.5),
#  ('freecell', 'FreeCell;', 0.941),
#  ('Timeline', 'टाइम-लाइन', 0.632),
#  ('Install', 'प्रविष्ट', 0.5),
#  ('Dvdcss', 'Dvdcss', 1.0),
#  ('This', 'ही', 0.667),
#  ('NAT Binding', 'बाइंडिंग', 0.5),
#  ('Debugging', 'डिबगिंग', 0.556),
#  ('Romanian', 'रोमानियन', 0.889),
#  ('Profiling Data', 'प्रोफाईलिंग', 0.615),
#  ('Danish', 'दानिश', 0.923),
#  ('Patch', 'पैचेस', 0.615),
#  ('Sentbox', 'सेण्टबाक्स', 0.588),
#  ('×%', '×%', 1.0),
#  ('DVD', 'DVD', 1.0),
#  ('This', 'इस', 0.571),
#  ('Yukon', 'युकान', 0.727),
#  ('ABCDEFGHIJK', 'abcdefghijk', 1.0),
#  ('XInput', 'XInput', 1.0),
#  ('Out', 'Out', 1.0),
#  ('Directory', 'डायरेक्ट्री', 0.526),
#  ('And', 'HEAD.', 0.5),
#  ('CIF', '(CIF', 0.857),
#  ('Args:% s', 'Args:%', 0.857),
#  ('Pixel Format', 'पिक्सेल', 0.526),
#  ('Alt', 'आल्ट', 0.857),
#  ('la', 'का', 0.5),
#  ('Online', 'ऑनलाइन', 0.571),
#  ('Trace', 'ट्रेस', 0.6),
#  ('Swedish', 'स्वीडिश', 0.667),
#  ('New', 'नए', 0.667),
#  ('API', 'हैलो', 0.5),
#  ('Franklin St', 'Franklin', 0.842),
#  ('Margin', 'मार्जिन', 0.769),
#  ('PARTICULAR', 'प्रतिलिपि', 0.526),
#  ('Filtering', 'फिल्टरिंग', 0.6),
#  ('Type', "'Type", 0.889),
#  ('TOS', '(TOS)', 0.75),
#  ('Libraries', 'लाइब्रेरी', 0.706),
#  ('Loaded', 'लोड', 0.6),
#  ('Glade', 'ग्लेड', 0.6),
#  ('Restore', '"Restore"', 0.875),
#  ('H. 323', '323', 0.667),
#  ('Mauve', 'Mauve', 1.0),
#  ('ANY', 'ANY', 1.0),
#  ('MH', 'MH', 1.0),
#  ('URIs', 'URI', 0.857),
#  ('Game', 'गेम', 0.5),
#  ('Lang', 'अल्ड', 0.5),
#  ('Naba Kumar', 'Kumar', 0.667),
#  ('Header', 'हेडर', 0.667),
#  ('Unnamed', 'अनाम', 0.5),
#  ('Armenian', 'रोमानियन', 0.556),
#  ('Step', 'स्टेप', 0.889),
#  ('Generic', 'ज़ेनेरिक', 0.667),
#  ('Ctrl', 'Ctrl-X', 0.8),
#  ('e. g. jabber', 'jabber.', 0.632),
#  ('ParamSpec', 'पैरामीटर्सः', 0.545),
#  ('Console', 'कन्सोल', 0.571),
#  ('Breakpoint', 'ब्रेकपाइन्ट', 0.762),
#  ('Configure', 'कॉन्फ़िगर', 0.526),
#  ('Tone', 'टोन', 0.75),
#  ('You', 'You', 1.0),
#  ('Cancel', 'चालू', 0.545),
#  ('Indent', 'इंडेन्टेशन', 0.556),
#  ('Style', 'से', 0.571),
#  ('Timeout', 'टाइमआउट', 0.625),
#  ('Dialpad', 'डॉयलपेड', 0.556),
#  ('Simulate', 'सिमुलेट', 0.75),
#  ('One', 'NONE,', 0.75),
#  ('UDP', 'UDP', 1.0),
#  ('MPEG2', 'MPEG2', 1.0),
#  ('Lunch', 'लंच', 0.545),
#  ('Add Breakpoint', 'ब्रेकपाइंट', 0.56),
#  ('CVSROOT', 'CVSROOT', 1.0),
#  ('String', 'स्ट्रिंग', 0.769),
#  ('Git Error', 'Error', 0.714),
#  ('Photo Path', 'पथ', 0.533),
#  ('Changes', 'चुनें', 0.615),
#  ('Plugin', 'प्लगिन.', 0.714),
#  ('Font', 'फ़ॉन्टः', 0.545),
#  ('Switch', 'स्विच', 0.667),
#  ('Search', 'असमर्थ', 0.533),
#  ('CoglWinsys', 'CoglWinsys', 1.0),
#  ('Pro', 'प्रोजेक्ट', 0.545),
#  ('libburnia', 'Libburnia', 1.0),
#  ('High', 'है', 0.571),
#  ('Arguments', 'आर्गुमेंट्सः', 0.8),
#  ('Anjuta Shell', 'Anjuta', 0.667),
#  ('Grep', 'grep', 1.0),
#  ('WARRANTY', 'वारंटी', 0.533),
#  ('Refcount:%', 'रेफकाउन्ट:%', 0.609),
#  ('Generic', 'Generic', 1.0),
#  ('VCard', 'VCARD', 1.0),
#  ('Double', 'डबल', 0.5),
#  ('Drag Threshold', 'थ्रेशोल्ड', 0.75),
#  ('Messages', 'संदेश', 0.5),
#  ('BAR', 'BAR', 1.0),
#  ('don', 'विंडो', 0.5),
#  ('URI', 'URI:', 0.857),
#  ('Picture', 'picture"', 0.933),
#  ('Toolbar', 'बार', 0.545),
#  ('IMAP', 'IMAP', 1.0),
#  ('Japanese', 'जापानी', 0.714),
#  ('Decks', 'डेक', 0.667),
#  ('Please', 'से', 0.5),
#  ('List', 'लिए', 0.571),
#  ('Mouse Input', 'इनपुट', 0.556),
#  ('Quatorze', 'क्वातोर्जे', 0.625),
#  ('Program', 'प्रोग्राम', 0.933),
#  ('Brasero', 'ब्रैसेरो-नया', 0.7),
#  ('Foundation', 'Foundation;', 0.952),
#  ('Tag', 'टैग', 0.75),
#  ('Profile', 'प्रोजेक्ट', 0.533),
#  ('Margin', 'ऊंचाई', 0.5),
#  ('Paper', 'super', 0.6),
#  ('BSD', 'बीएसडी', 0.6),
#  ('Blurb', 'Blurb', 1.0),
#  ('Cancel', 'करने', 0.5),
#  ('Lithuanian', 'लिथानियान', 0.857),
#  ('Street', 'Street,', 0.923),
#  ('Times', 'टाइम्स,', 0.667),
#  ('Macro', 'मैक्रो', 0.727),
#  ('Celtic', 'सेल्टिक', 0.615),
#  ('Offline', 'ऑफ़लाइन', 0.533),
#  ('IMAP', 'एम', 0.571),
#  ('Match', 'इंच.', 0.545),
#  ('Valentine', 'वेलेंटाइन', 0.632),
#  ('State', 'स्थिति', 0.545),
#  ('Balsa', 'बाल्स', 1.0),
#  ('Headers', 'हेडर', 0.615),
#  ('spin button', 'स्पिन', 0.5),
#  ('Calls', '(Balsa', 0.545),
#  ('Build Module', 'मोड्यूल', 0.526),
#  ('Balsa', 'बल्सा', 1.0),
#  ('Zoom', 'ज़ूम', 0.5),
#  ('Brasero - Copying', 'ब्रैसेरो-सीडी', 0.6),
#  ('NTSC', 'NTSC', 1.0),
#  ('Swap', 'Swap.', 0.889),
#  ('Estonian', 'एस्टोनियन', 0.889),
#  ('Package:% s', 'पैकेजः%', 0.5),
#  ('Header:%', 'हेडर', 0.571),
#  ('Print', 'प्रिंट', 0.727),
#  ('Has', 'है', 0.667),
#  ('Border', 'बार्डर', 0.615),
#  ('Note', 'नोटः', 0.667),
#  ('Save', 'दस्तावेज', 0.615),
#  ('Presentation', 'प्रस्तुति', 0.6),
#  ('Search', '"Search"', 0.857),
#  ('Toggle Breakpoint', 'ब्रेकपाइन्ट', 0.571),
#  ('Space', 'स्पेसर', 0.5),
#  ('SSH', 'SSH', 1.0),
#  ('Build', 'बिल्ड', 0.8),
#  ('Modules', 'मॉड्यूल्सः', 0.588),
#  ('GLSL', 'ARBfp/GLSL', 0.571),
#  ('PATH', 'PATH', 1.0),
#  ('Static', '"Static', 0.923),
#  ('What', 'चाहते', 0.545),
#  ('Contrast', 'कंट्रास्ट', 0.588),
#  ('Anjuta', 'Anjuta.', 0.923),
#  ('Sentbox', 'सेटबाक्स', 0.5),
#  ('DirectX', 'DirectX', 1.0),
#  ('Path', 'पथः', 0.8),
#  ('Gnome', 'जीनोम', 0.545),
#  ('Less', 'लिए', 0.571),
#  ('Files', 'फ़ाइलें', 0.727),
#  ('Valgrind', 'वेलग्रिंड', 0.667),
#  ('Debugger', 'दूर', 0.5),
#  ('Network', 'नेटवर्किंग', 0.526),
#  ('Tags', 'टैग्स', 0.8),
#  ('Smart', 'स्मार्ट', 0.909),
#  ('DVD', 'DVD-R', 0.75),
#  ('Profile Name', 'प्रोफ़ाइल', 0.7),
#  ('Dvd', 'Dvd', 1.0),
#  ('ISDN', 'ISDN,', 0.889),
#  ('XVideo', 'XVideo', 1.0),
#  ('Compile', 'कम्पाइल', 0.533),
#  ('Presentation', 'presentation"', 0.96),
#  ('Java', '+/Java', 0.8),
#  ('org', 'org', 1.0),
#  ('NOTE', 'नोटः', 0.667),
#  ('Triple', 'तिहरी', 0.5),
#  ('GdkWindowState', 'GdkWindowState', 1.0),
#  ('Shortcut', 'शार्टकट', 0.556),
#  ('Ekiga', 'Ekiga', 1.0),
#  ('Syntax', 'सिन्टेक्स', 0.571),
#  ('CLang', 'CLang', 1.0),
#  ('Europe', '(यूरोप)', 0.571),
#  ('KB', 'केेबी', 0.571),
#  ('Clipboard', 'क्लिपबोर्ड', 0.737),
#  ('Seahaven', 'सीहैवन', 0.588),
#  ('Search', 'संग्रहित', 0.5),
#  ('Fold', 'कोड', 0.5),
#  ('Folder', 'फ़ोल्डर', 0.769),
#  ('Italic', 'ईटैलिक', 0.714),
#  ('None', 'content', 0.545),
#  ('Profiles', 'प्रोफ़ाइल', 0.75),
#  ('Take', 'तस्वीरें', 0.5),
#  ('Anjuta', 'अंजूटा', 0.833),
#  ('IDE', 'IDE', 1.0),
#  ('Castle', 'सताने', 0.5),
#  ('Tracks', 'ट्रैक्स', 0.769),
#  ('Arabic', 'अरबी', 0.909),
#  ('ge', 'g)', 0.5),
#  ('Table', 'स्तंभ', 0.5),
#  ('Pages', 'पन्ने', 0.6),
#  ('Linux', 'लिनक्स', 0.5),
#  ('Generic', 'जेनेरिक', 0.667),
#  ('dialog4', 'डायलाग', 0.533),
#  ('Pixbuf', 'pixbut', 0.833),
#  ('Kings', 'किंग', 0.6),
#  ('Thai', 'थाई', 1.0),
#  ('History', 'हिस्सा', 0.5),
#  ('MDI', 'एमडीआई', 0.6),
#  ('Stars', 'तारे', 0.667),
#  ('Toggle', 'टागल', 0.5),
#  ('Korean', 'कोरियाई', 0.615),
#  ('Mobile Phone', 'मोबाईल', 0.526),
#  ('Libburnia', 'Libburnia', 1.0),
#  ('Auld', 'अल्ड', 0.75),
#  ('Commit', 'Commit', 1.0),
#  ('Nordic', 'नोर्डिक', 0.769),
#  ('Final', 'फाइनल', 0.615),
#  ('Press', 'प्रेस', 0.8),
#  ('Highest', 'Highest', 1.0),
#  ('Snippets', 'स्निपेट', 0.8),
#  ('Video Mode', 'वीडियो', 0.5),
#  ('Russian', 'रूसी', 0.727),
#  ('Sentbox', 'सेन्टबाक्स', 0.588),
#  ('Devices', 'डिवाइस', 0.571),
#  ('SAS', 'SAS', 1.0),
#  ('Remote', '(रिमोट)', 0.571),
#  ('Details:%', 'फाइल%', 0.5),
#  ('Web', 'वेब', 0.571),
#  ('Build', 'जेबिल्डर', 0.571),
#  ('All', "'All", 0.857),
#  ('Password', 'पासवर्डः', 0.556),
#  ('CoglObjects', 'CoglObjects', 1.0),
#  ('Pointer', 'प्वाइंटर', 0.5),
#  ('Markers', 'मार्कर्स', 0.8),
#  ('GNOME Terminal', 'टर्मिनल', 0.609),
#  ('Server', 'सर्वर', 0.615),
#  ('Fast', 'फास्ट', 0.6),
#  ('Layout', 'लेआउट', 0.667),
#  ('Anjuta', 'अंजुटा', 0.833),
#  ('Devhelp', 'लिएDevhelp', 0.824),
#  ('VoIP', 'VoIP', 1.0),
#  ('Developer', 'डेवलेपर', 0.632),
#  ('API Tags', 'Tags', 0.667),
#  ('Baobab', 'Baobab', 1.0),
#  ('Web', 'white', 0.5),
#  ('Tree', 'ट्री', 0.571),
#  ('Anjuta', 'Anjuta', 1.0),
#  ('DTMF', 'DTMF', 1.0),
#  ('TEXT', 'CD-TEXT', 0.727),
#  ('WIDGET', 'विडजेट', 0.571),
#  ('Alt', 'Alt', 1.0),
#  ('Quality', 'बाइट', 0.5),
#  ('Brasero - Copying', 'ब्रैसेरो-नक़ल', 0.562),
#  ('Playlist', '"Playlist".', 0.842),
#  ('IDE', 'आईडीई', 0.5),
#  ('Fonts', 'फान्ट्स', 0.5),
#  ('Git', 'input', 0.5),
#  ('Button', 'बटन', 0.5),
#  ('Aisleriot', 'एस्लेरियाट', 0.632),
#  ('status%', 'साथ', 0.5),
#  ('Beagle', 'बीगल', 0.5),
#  ('Glade', 'बदलें', 0.5),
#  ('SVCDs', 'SVCDs', 1.0),
#  ('with% s', 'with%', 0.833),
#  ('Trade', 'ट्रैड', 0.727),
#  ('Italic', 'इटालिक', 0.769),
#  ('Files', 'फ़ाइलः', 0.545),
#  ('H. 323v2', '323v2', 0.769),
#  ('Calltips', 'कालटिप्स', 0.706),
#  ('Lex', 'लिए', 0.667),
#  ('Static', 'स्थिर', 0.5),
#  ('Message', 'संदेशः', 0.5),
#  ('Expedited', 'एक्सपेडीडेट', 0.571),
#  ('Disable', 'सभी', 0.5),
#  ('Caribou', 'कैरिबू', 0.714),
#  ('Statement', 'स्टेटमेन्ट', 0.737),
#  ('Helsinki', 'हेलसिंकी', 0.824),
#  ('DVD', 'Dvd', 1.0),
#  ('Redheads', 'रेडहेड', 0.75),
#  ('Folder', 'फोल्डर', 0.571),
#  ('Websites', 'वेबसाईट', 0.588),
#  ('Repositories', 'रिपॉजिटरीः', 0.5),
#  ('Kansas', 'कैनसास', 0.8),
#  ('e. g. ekiga', 'ekiga.', 0.588),
#  ('Update', 'Update', 1.0),
#  ('Anjuta Shell', 'अंजूटा', 0.556),
#  ('Revert', 'रिसेट', 0.5),
#  ('Editor', 'एडिटर', 0.769),
#  ('Ringing', 'रिंगिंग', 0.667),
#  ('OpenGL', 'OpenGL', 1.0),
#  ('Anjuta Plugin', 'प्लगिन', 0.5),
#  ('Scale Gravity', 'ग्रैविटी', 0.571),
#  ('Fast', 'फार्स्ट', 0.545),
#  ('CLang Paths', 'पथ', 0.5),
#  ('This', 'This', 1.0),
#  ('Devhelp', 'डेवहेल्प', 0.875),
#  ('Shelf', 'शेल्फ', 0.667),
#  ('Call', 'Call', 1.0),
#  ('IM', 'आईएम', 0.571),
#  ('Markers', 'करें', 0.5),
#  ('Working', '[Head/Working', 0.7),
#  ('Start', 'स्टार्ट', 0.909),
#  ('Contain', 'नहीं', 0.5),
#  ('Bug Buddy', 'bug-buddy,', 0.842),
#  ('GNOME', 'गनोम', 0.727),
#  ('Pan', 'पैन', 0.75),
#  ('Live', 'लाइव', 0.667),
#  ('Mask', 'मास्क', 0.889),
#  ('Startup', 'स्टार्टअप', 0.75),
#  ('Reply', 'एल', 0.5),
#  ('Manual', 'नियमावली', 0.5),
#  ('Snippet Name', 'स्निपेट', 0.737),
#  ('GNOME Games', 'ग्नोम', 0.625),
#  ('Pixmap', 'Pixmap', 1.0),
#  ('PyGTK', 'PyGTK', 1.0),
#  ('Disconnected', 'डिस्कनेक्टेड', 0.667),
#  ('Cairo', 'कैरो', 0.8),
#  ('SECAM', 'PAL/SECAM', 0.714),
#  ('driver doesn', 'ड्राइवर', 0.5),
#  ('Chart', 'चार्ट', 0.909),
#  ('Client', 'लिए', 0.667),
#  ('HTTP', '(HTTP)', 0.8),
#  ('Characters', 'अछर', 0.625),
#  ('Boolean', 'बूलियन', 0.533),
#  ('This', 'ठीक', 0.667),
#  ('Video', 'लिए', 0.5),
#  ('Patch Plugin', 'प्लगिन', 0.526),
#  ('Shagadelic', 'Shagadelic', 1.0),
#  ('API', 'एपीआई', 0.5),
#  ('Status', 'स्थिति', 0.5),
#  ('IMAP', 'पाप', 0.5),
#  ('Object', 'ऑब्जेक्ट', 0.615),
#  ('Rounds', 'राउंड', 0.5),
#  ('Brasero', 'Brasero', 1.0),
#  ('Once', 'होने', 0.75),
#  ('FOR', 'FOR', 1.0),
#  ('Mail', 'फाइलें', 0.545),
#  ('IMAP', 'दिया', 0.5),
#  ('MMMM', 'MMMM', 1.0),
#  ('Page', 'पेज', 0.5),
#  ('The%', 'रहे', 0.5),
#  ('Date', 'date', 1.0),
#  ('Please', 'आपसे', 0.727),
#  ('GUI', 'GUI', 1.0),
#  ('Interval', 'अंतराल', 0.5),
#  ('Monospace', 'मोनोस्पेस', 0.778),
#  ('Todo', 'टूडू', 0.5),
#  ('QCIF', '(QCIF', 0.889),
#  ('GTK', 'GTK', 1.0),
#  ('Jitter', 'Jitter', 1.0),
#  ('Late', 'Late', 1.0),
#  ('Short', 'छोटा', 0.6),
#  ('New Project', 'प्रोजेक्ट', 0.632),
#  ('Filesystem', 'फाइलसिस्टम', 0.522),
#  ('Predictive', 'प्रविष्टि', 0.526),
#  ('Remote', 'रिमोट', 0.667),
#  ('ADDRESS', '@एड्रेस', 0.571),
#  ('Klondike', 'Klondike,', 0.941),
#  ('Memory', 'मेमोरी', 0.833),
#  ('filter:% s', 'लिए:%', 0.533),
#  ('INFO', '"INFO"', 0.8),
#  ('Lua', 'u', 0.5),
#  ('Challenge', 'Challenge:', 0.947),
#  ('SamplePlugin', 'SamplePlugin', 1.0),
#  ('Score', 'सकोरः', 0.5),
#  ('Brasero - Burning', 'ब्रैसेरो-डिस्क', 0.581),
#  ('Module', 'माॅड्यूल', 0.533),
#  ('Paths', 'पथः', 0.727),
#  ('Brasero - Disc Copy', 'ब्रैसेरो-डिस्क', 0.667),
#  ('GPL', '(GPL)', 0.75),
#  ('Text', 'टेक्स्ट', 0.6),
#  ('Path', 'पथ', 0.889),
#  ('URIs', 'यूआरआई', 0.545),
#  ('TSTO', 'TSTO', 1.0),
#  ('Loader', 'लोडर', 0.667),
#  ('Telephony', 'IP-टेलिफोनी', 0.667),
#  ('Zebra', 'जेब्राcard', 0.571),
#  ('Expression', 'एक्सप्रेशन', 0.545),
#  ('Buddy', 'bug-buddy,', 0.667),
#  ('Font Name', 'फ़ॉन्ट', 0.533),
#  ('Libisofs', 'Libisofs', 1.0),
#  ('This', 'स्थिति', 0.6),
#  ('DVDs', 'डीवीडी', 0.6),
#  ('PIN', 'PIN', 1.0),
#  ('Port', 'पोर्ट', 0.889),
#  ('ANY', 'any', 1.0),
#  ('API', 'API', 1.0),
#  ('Plugin', 'प्लगइनः', 0.667),
#  ('Burner', 'ब्रेसेरो', 0.615),
#  ('Disc', 'सीडी', 0.5),
#  ('XML', 'XML-RPC', 0.6),
#  ('Shader', 'शेडर', 0.615),
#  ('License', 'लिए', 0.6),
#  ('Reset', 'सेट', 0.667),
#  ('Stage', 'स्टेज', 0.6),
#  ('Scan Folder', 'फ़ोल्डर', 0.556),
#  ('Editor', 'Editor', 1.0),
#  ...]
